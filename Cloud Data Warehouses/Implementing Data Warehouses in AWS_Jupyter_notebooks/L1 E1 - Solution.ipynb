# %% [markdown]
# # Demo 01 -  Sakila Star Schema & ETL
#
# All the database tables in this demo are based on public database samples and transformations
# - `Sakila` is a sample database created by `MySql` [Link](https://dev.mysql.com/doc/sakila/en/sakila-structure.html)
# - The postgresql version of it is called `Pagila` [Link](https://github.com/devrimgunduz/pagila)
# - The facts and dimension tables design is based on O'Reilly's public dimensional modelling tutorial schema [Link](http://archive.oreilly.com/oreillyschool/courses/dba3/index.html)

# %% [markdown]
# # STEP0: Using ipython-sql
#
# - load ipython-sql: `%load_ext sql`
#
# - To execute SQL queries you write one of the following atop of your cell:
#     - `%sql`
#         - For a one-liner SQL query
#         - You can access a python var using `$`
#     - `%%sql`
#         - For a multi-line SQL query
#         - You can **NOT** access a python var using `$`
#
#
# - Running a connection string like:
# `postgresql://postgres:postgres@db:5432/pagila` connects to the database

# %% [markdown]
# # STEP1 : Connect to the local database where Pagila is loaded

# %% [markdown]
# ##  1.1 Create the pagila db and fill it with data
# - Adding `"!"` at the beginning of a jupyter cell runs a command in a shell, i.e. we are not running python code but we are running the `createdb` and `psql` postgresql commmand-line utilities

# %%
# !PGPASSWORD=student createdb -h 127.0.0.1 -U student pagila
# !PGPASSWORD=student psql -q -h 127.0.0.1 -U student -d pagila -f Data/pagila-schema.sql
# !PGPASSWORD=student psql -q -h 127.0.0.1 -U student -d pagila -f Data/pagila-data.sql
# Out:
# createdb: database creation failed: ERROR:  database "pagila" already exists
# psql:Data/pagila-schema.sql:43: ERROR:  type "mpaa_rating" already exists
# psql:Data/pagila-schema.sql:53: ERROR:  type "year" already exists
# psql:Data/pagila-schema.sql:70: ERROR:  function "_group_concat" already exists with same argument types
# psql:Data/pagila-schema.sql:87: ERROR:  function "film_in_stock" already exists with same argument types
# psql:Data/pagila-schema.sql:104: ERROR:  function "film_not_in_stock" already exists with same argument types
# psql:Data/pagila-schema.sql:149: ERROR:  function "get_customer_balance" already exists with same argument types
# psql:Data/pagila-schema.sql:171: ERROR:  function "inventory_held_by_customer" already exists with same argument types
# psql:Data/pagila-schema.sql:208: ERROR:  function "inventory_in_stock" already exists with same argument types
# psql:Data/pagila-schema.sql:226: ERROR:  function "last_day" already exists with same argument types
# psql:Data/pagila-schema.sql:241: ERROR:  function "last_updated" already exists with same argument types
# psql:Data/pagila-schema.sql:255: ERROR:  relation "customer_customer_id_seq" already exists
# psql:Data/pagila-schema.sql:279: ERROR:  relation "customer" already exists
# psql:Data/pagila-schema.sql:343: ERROR:  function "rewards_report" already exists with same argument types
# psql:Data/pagila-schema.sql:355: ERROR:  function "group_concat" already exists with same argument types
# psql:Data/pagila-schema.sql:369: ERROR:  relation "actor_actor_id_seq" already exists
# psql:Data/pagila-schema.sql:383: ERROR:  relation "actor" already exists
# psql:Data/pagila-schema.sql:397: ERROR:  relation "category_category_id_seq" already exists
# psql:Data/pagila-schema.sql:410: ERROR:  relation "category" already exists
# psql:Data/pagila-schema.sql:424: ERROR:  relation "film_film_id_seq" already exists
# psql:Data/pagila-schema.sql:448: ERROR:  relation "film" already exists
# psql:Data/pagila-schema.sql:461: ERROR:  relation "film_actor" already exists
# psql:Data/pagila-schema.sql:474: ERROR:  relation "film_category" already exists
# psql:Data/pagila-schema.sql:497: ERROR:  relation "actor_info" already exists
# psql:Data/pagila-schema.sql:511: ERROR:  relation "address_address_id_seq" already exists
# psql:Data/pagila-schema.sql:529: ERROR:  relation "address" already exists
# psql:Data/pagila-schema.sql:543: ERROR:  relation "city_city_id_seq" already exists
# psql:Data/pagila-schema.sql:557: ERROR:  relation "city" already exists
# psql:Data/pagila-schema.sql:571: ERROR:  relation "country_country_id_seq" already exists
# psql:Data/pagila-schema.sql:584: ERROR:  relation "country" already exists
# psql:Data/pagila-schema.sql:609: ERROR:  relation "customer_list" already exists
# psql:Data/pagila-schema.sql:632: ERROR:  relation "film_list" already exists
# psql:Data/pagila-schema.sql:646: ERROR:  relation "inventory_inventory_id_seq" already exists
# psql:Data/pagila-schema.sql:660: ERROR:  relation "inventory" already exists
# psql:Data/pagila-schema.sql:674: ERROR:  relation "language_language_id_seq" already exists
# psql:Data/pagila-schema.sql:687: ERROR:  relation "language" already exists
# psql:Data/pagila-schema.sql:710: ERROR:  relation "nicer_but_slower_film_list" already exists
# psql:Data/pagila-schema.sql:724: ERROR:  relation "payment_payment_id_seq" already exists
# psql:Data/pagila-schema.sql:740: ERROR:  relation "payment" already exists
# psql:Data/pagila-schema.sql:751: ERROR:  relation "rental_rental_id_seq" already exists
# psql:Data/pagila-schema.sql:768: ERROR:  relation "rental" already exists
# psql:Data/pagila-schema.sql:787: ERROR:  relation "sales_by_film_category" already exists
# psql:Data/pagila-schema.sql:801: ERROR:  relation "staff_staff_id_seq" already exists
# psql:Data/pagila-schema.sql:822: ERROR:  relation "staff" already exists
# psql:Data/pagila-schema.sql:836: ERROR:  relation "store_store_id_seq" already exists
# psql:Data/pagila-schema.sql:850: ERROR:  relation "store" already exists
# psql:Data/pagila-schema.sql:872: ERROR:  relation "sales_by_store" already exists
# psql:Data/pagila-schema.sql:893: ERROR:  relation "staff_list" already exists
# psql:Data/pagila-schema.sql:903: ERROR:  multiple primary keys for table "actor" are not allowed
# psql:Data/pagila-schema.sql:911: ERROR:  multiple primary keys for table "address" are not allowed
# psql:Data/pagila-schema.sql:919: ERROR:  multiple primary keys for table "category" are not allowed
# psql:Data/pagila-schema.sql:927: ERROR:  multiple primary keys for table "city" are not allowed
# psql:Data/pagila-schema.sql:935: ERROR:  multiple primary keys for table "country" are not allowed
# psql:Data/pagila-schema.sql:944: ERROR:  multiple primary keys for table "film_actor" are not allowed
# psql:Data/pagila-schema.sql:952: ERROR:  multiple primary keys for table "film_category" are not allowed
# psql:Data/pagila-schema.sql:960: ERROR:  multiple primary keys for table "film" are not allowed
# psql:Data/pagila-schema.sql:968: ERROR:  multiple primary keys for table "inventory" are not allowed
# psql:Data/pagila-schema.sql:976: ERROR:  multiple primary keys for table "language" are not allowed
# psql:Data/pagila-schema.sql:984: ERROR:  multiple primary keys for table "rental" are not allowed
# psql:Data/pagila-schema.sql:992: ERROR:  multiple primary keys for table "staff" are not allowed
# psql:Data/pagila-schema.sql:1000: ERROR:  multiple primary keys for table "store" are not allowed
# psql:Data/pagila-schema.sql:1007: ERROR:  relation "film_fulltext_idx" already exists
# psql:Data/pagila-schema.sql:1014: ERROR:  relation "idx_actor_last_name" already exists
# psql:Data/pagila-schema.sql:1021: ERROR:  relation "idx_fk_address_id" already exists
# psql:Data/pagila-schema.sql:1028: ERROR:  relation "idx_fk_city_id" already exists
# psql:Data/pagila-schema.sql:1035: ERROR:  relation "idx_fk_country_id" already exists
# psql:Data/pagila-schema.sql:1042: ERROR:  relation "idx_fk_customer_id" already exists
# psql:Data/pagila-schema.sql:1049: ERROR:  relation "idx_fk_film_id" already exists
# psql:Data/pagila-schema.sql:1056: ERROR:  relation "idx_fk_inventory_id" already exists
# psql:Data/pagila-schema.sql:1063: ERROR:  relation "idx_fk_language_id" already exists
# psql:Data/pagila-schema.sql:1070: ERROR:  relation "idx_fk_original_language_id" already exists
# psql:Data/pagila-schema.sql:1077: ERROR:  relation "idx_fk_payment_customer_id" already exists
# psql:Data/pagila-schema.sql:1083: ERROR:  relation "idx_fk_payment_staff_id" already exists
# psql:Data/pagila-schema.sql:1092: ERROR:  relation "idx_fk_store_id" already exists
# psql:Data/pagila-schema.sql:1099: ERROR:  relation "idx_last_name" already exists
# psql:Data/pagila-schema.sql:1106: ERROR:  relation "idx_store_id_film_id" already exists
# psql:Data/pagila-schema.sql:1113: ERROR:  relation "idx_title" already exists
# psql:Data/pagila-schema.sql:1120: ERROR:  relation "idx_unq_manager_staff_id" already exists
# psql:Data/pagila-schema.sql:1127: ERROR:  relation "idx_unq_rental_rental_date_inventory_id_customer_id" already exists
# psql:Data/pagila-schema.sql:1133: ERROR:  trigger "film_fulltext_trigger" for relation "film" already exists
# psql:Data/pagila-schema.sql:1140: ERROR:  trigger "last_updated" for relation "actor" already exists
# psql:Data/pagila-schema.sql:1147: ERROR:  trigger "last_updated" for relation "address" already exists
# psql:Data/pagila-schema.sql:1154: ERROR:  trigger "last_updated" for relation "category" already exists
# psql:Data/pagila-schema.sql:1161: ERROR:  trigger "last_updated" for relation "city" already exists
# psql:Data/pagila-schema.sql:1168: ERROR:  trigger "last_updated" for relation "country" already exists
# psql:Data/pagila-schema.sql:1175: ERROR:  trigger "last_updated" for relation "customer" already exists
# psql:Data/pagila-schema.sql:1182: ERROR:  trigger "last_updated" for relation "film" already exists
# psql:Data/pagila-schema.sql:1189: ERROR:  trigger "last_updated" for relation "film_actor" already exists
# psql:Data/pagila-schema.sql:1196: ERROR:  trigger "last_updated" for relation "film_category" already exists
# psql:Data/pagila-schema.sql:1203: ERROR:  trigger "last_updated" for relation "inventory" already exists
# psql:Data/pagila-schema.sql:1210: ERROR:  trigger "last_updated" for relation "language" already exists
# psql:Data/pagila-schema.sql:1217: ERROR:  trigger "last_updated" for relation "rental" already exists
# psql:Data/pagila-schema.sql:1224: ERROR:  trigger "last_updated" for relation "staff" already exists
# psql:Data/pagila-schema.sql:1231: ERROR:  trigger "last_updated" for relation "store" already exists
# psql:Data/pagila-schema.sql:1239: ERROR:  constraint "address_city_id_fkey" for relation "address" already exists
# psql:Data/pagila-schema.sql:1247: ERROR:  constraint "city_country_id_fkey" for relation "city" already exists
# psql:Data/pagila-schema.sql:1255: ERROR:  constraint "customer_address_id_fkey" for relation "customer" already exists
# psql:Data/pagila-schema.sql:1263: ERROR:  constraint "customer_store_id_fkey" for relation "customer" already exists
# psql:Data/pagila-schema.sql:1271: ERROR:  constraint "film_actor_actor_id_fkey" for relation "film_actor" already exists
# psql:Data/pagila-schema.sql:1279: ERROR:  constraint "film_actor_film_id_fkey" for relation "film_actor" already exists
# psql:Data/pagila-schema.sql:1287: ERROR:  constraint "film_category_category_id_fkey" for relation "film_category" already exists
# psql:Data/pagila-schema.sql:1295: ERROR:  constraint "film_category_film_id_fkey" for relation "film_category" already exists
# psql:Data/pagila-schema.sql:1303: ERROR:  constraint "film_language_id_fkey" for relation "film" already exists
# psql:Data/pagila-schema.sql:1311: ERROR:  constraint "film_original_language_id_fkey" for relation "film" already exists
# psql:Data/pagila-schema.sql:1319: ERROR:  constraint "inventory_film_id_fkey" for relation "inventory" already exists
# psql:Data/pagila-schema.sql:1327: ERROR:  constraint "inventory_store_id_fkey" for relation "inventory" already exists
# psql:Data/pagila-schema.sql:1334: ERROR:  constraint "rental_customer_id_fkey" for relation "rental" already exists
# psql:Data/pagila-schema.sql:1342: ERROR:  constraint "rental_inventory_id_fkey" for relation "rental" already exists
# psql:Data/pagila-schema.sql:1350: ERROR:  constraint "rental_staff_id_fkey" for relation "rental" already exists
# psql:Data/pagila-schema.sql:1358: ERROR:  constraint "staff_address_id_fkey" for relation "staff" already exists
# psql:Data/pagila-schema.sql:1366: ERROR:  constraint "staff_store_id_fkey" for relation "staff" already exists
# psql:Data/pagila-schema.sql:1374: ERROR:  constraint "store_address_id_fkey" for relation "store" already exists
# psql:Data/pagila-schema.sql:1384: ERROR:  constraint "payment_customer_id_fkey" for relation "payment" already exists
# psql:Data/pagila-data.sql:224: ERROR:  duplicate key value violates unique constraint "actor_pkey"
# DETAIL:  Key (actor_id)=(1) already exists.
# CONTEXT:  COPY actor, line 1
# psql:Data/pagila-data.sql:341: ERROR:  duplicate key value violates unique constraint "country_pkey"
# DETAIL:  Key (country_id)=(1) already exists.
# CONTEXT:  COPY country, line 1
# psql:Data/pagila-data.sql:949: ERROR:  duplicate key value violates unique constraint "city_pkey"
# DETAIL:  Key (city_id)=(1) already exists.
# CONTEXT:  COPY city, line 1
# psql:Data/pagila-data.sql:1560: ERROR:  duplicate key value violates unique constraint "address_pkey"
# DETAIL:  Key (address_id)=(1) already exists.
# CONTEXT:  COPY address, line 1
# psql:Data/pagila-data.sql:1584: ERROR:  duplicate key value violates unique constraint "category_pkey"
# DETAIL:  Key (category_id)=(1) already exists.
# CONTEXT:  COPY category, line 1
# psql:Data/pagila-data.sql:1594: ERROR:  duplicate key value violates unique constraint "store_pkey"
# DETAIL:  Key (store_id)=(1) already exists.
# CONTEXT:  COPY store, line 1
# psql:Data/pagila-data.sql:2201: ERROR:  duplicate key value violates unique constraint "customer_pkey"
# DETAIL:  Key (customer_id)=(1) already exists.
# CONTEXT:  COPY customer, line 1
# psql:Data/pagila-data.sql:2215: ERROR:  duplicate key value violates unique constraint "language_pkey"
# DETAIL:  Key (language_id)=(1) already exists.
# CONTEXT:  COPY language, line 1
# psql:Data/pagila-data.sql:3223: ERROR:  duplicate key value violates unique constraint "film_pkey"
# DETAIL:  Key (film_id)=(1) already exists.
# CONTEXT:  COPY film, line 1: "1	ACADEMY DINOSAUR	A Epic Drama of a Feminist And a Mad Scientist who must Battle a Teacher in The C..."
# psql:Data/pagila-data.sql:8693: ERROR:  duplicate key value violates unique constraint "film_actor_pkey"
# DETAIL:  Key (actor_id, film_id)=(1, 1) already exists.
# CONTEXT:  COPY film_actor, line 1
# psql:Data/pagila-data.sql:9701: ERROR:  duplicate key value violates unique constraint "film_category_pkey"
# DETAIL:  Key (film_id, category_id)=(1, 6) already exists.
# CONTEXT:  COPY film_category, line 1
# psql:Data/pagila-data.sql:14290: ERROR:  duplicate key value violates unique constraint "inventory_pkey"
# DETAIL:  Key (inventory_id)=(1) already exists.
# CONTEXT:  COPY inventory, line 1
# psql:Data/pagila-data.sql:14300: ERROR:  duplicate key value violates unique constraint "staff_pkey"
# DETAIL:  Key (staff_id)=(1) already exists.
# CONTEXT:  COPY staff, line 1
# psql:Data/pagila-data.sql:30352: ERROR:  duplicate key value violates unique constraint "rental_pkey"
# DETAIL:  Key (rental_id)=(2) already exists.
# CONTEXT:  COPY rental, line 1
#  setval
# --------
#     200
# (1 row)
#
#  setval
# --------
#     605
# (1 row)
#
#  setval
# --------
#      16
# (1 row)
#
#  setval
# --------
#     600
# (1 row)
#
#  setval
# --------
#     109
# (1 row)
#
#  setval
# --------
#     599
# (1 row)
#
#  setval
# --------
#    1000
# (1 row)
#
#  setval
# --------
#    4581
# (1 row)
#
#  setval
# --------
#       6
# (1 row)
#
#  setval
# --------
#   32098
# (1 row)
#
#  setval
# --------
#   16049
# (1 row)
#
#  setval
# --------
#       2
# (1 row)
#
#  setval
# --------
#       2
# (1 row)

# %% [markdown]
# ## 1.2 Connect to the newly created db

# %%
# %load_ext sql

# %%
DB_ENDPOINT = "127.0.0.1"
DB = 'pagila'
DB_USER = 'student'
DB_PASSWORD = 'student'
DB_PORT = '5432'

# postgresql://username:password@host:port/database
conn_string = "postgresql://{}:{}@{}:{}/{}" \
                        .format(DB_USER, DB_PASSWORD, DB_ENDPOINT, DB_PORT, DB)

print(conn_string)
# Out:
# postgresql://student:student@127.0.0.1:5432/pagila

# %%
# %sql $conn_string
# Out:
# 'Connected: student@pagila'

# %% [markdown]
# # STEP 1.1: Create and populate the star schema

# %% [markdown]
# # STEP2 : Explore the  3NF Schema

# %% [markdown]
# <img src="./pagila-3nf.png" width="50%"/>

# %% [markdown]
# ## 2.1 How much? What data sizes are we looking at?

# %%
nStores = %sql select count(*) from store;
nFilms = %sql select count(*) from film;
nCustomers = %sql select count(*) from customer;
nRentals = %sql select count(*) from rental;
nPayment = %sql select count(*) from payment;
nStaff = %sql select count(*) from staff;
nCity = %sql select count(*) from city;
nCountry = %sql select count(*) from country;

print("nFilms\t\t=", nFilms[0][0])
print("nCustomers\t=", nCustomers[0][0])
print("nRentals\t=", nRentals[0][0])
print("nPayment\t=", nPayment[0][0])
print("nStaff\t\t=", nStaff[0][0])
print("nStores\t\t=", nStores[0][0])
print("nCities\t\t=", nCity[0][0])
print("nCountry\t\t=", nCountry[0][0])
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
# nFilms		= 1000
# nCustomers	= 599
# nRentals	= 16044
# nPayment	= 80245
# nStaff		= 2
# nStores		= 2
# nCities		= 600
# nCountry		= 109

# %% [markdown]
# ## 2.2 When? What time period are we talking about?

# %%
# %%sql
# select min(payment_date) as start, max(payment_date) as end from payment;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 1 rows affected.
# [(datetime.datetime(2017, 1, 24, 21, 21, 56, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), datetime.datetime(2017, 5, 14, 13, 44, 29, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)))]

# %% [markdown]
# ## 2.3 Where? Where do events in this database occur?

# %%
# %%sql
# select district,  sum(city_id) as n
# from address
# group by district
# order by n desc
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 10 rows affected.
# [('Shandong', 3237),
#  ('England', 2974),
#  ('So Paulo', 2952),
#  ('West Bengali', 2623),
#  ('Buenos Aires', 2572),
#  ('Uttar Pradesh', 2462),
#  ('California', 2444),
#  ('Southern Tagalog', 1931),
#  ('Tamil Nadu', 1807),
#  ('Hubei', 1790)]

# %% [markdown]
# # STEP3: Perform some simple data analysis

# %% [markdown]
# ## 3.1 Insight 1:   Top Grossing Movies
# - Payments amounts are in table `payment`
# - Movies are in table `film`
# - They are not directly linked, `payment` refers to a `rental`, `rental` refers to an `inventory` item and `inventory` item refers to a `film`
# - `payment` &rarr; `rental` &rarr; `inventory` &rarr; `film`

# %% [markdown]
# ### 3.1.1 Films

# %%
# %%sql
# select film_id, title, release_year, rental_rate, rating  from film limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# [(1, 'ACADEMY DINOSAUR', 2006, Decimal('0.99'), 'PG'),
#  (2, 'ACE GOLDFINGER', 2006, Decimal('4.99'), 'G'),
#  (3, 'ADAPTATION HOLES', 2006, Decimal('2.99'), 'NC-17'),
#  (4, 'AFFAIR PREJUDICE', 2006, Decimal('2.99'), 'G'),
#  (5, 'AFRICAN EGG', 2006, Decimal('2.99'), 'G')]

# %% [markdown]
# ### 3.1.2 Payments

# %%
# %%sql
# select * from payment limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# [(16050, 269, 2, 7, Decimal('1.99'), datetime.datetime(2017, 1, 24, 21, 40, 19, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (16051, 269, 1, 98, Decimal('0.99'), datetime.datetime(2017, 1, 25, 15, 16, 50, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (16052, 269, 2, 678, Decimal('6.99'), datetime.datetime(2017, 1, 28, 21, 44, 14, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (16053, 269, 2, 703, Decimal('0.99'), datetime.datetime(2017, 1, 29, 0, 58, 2, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (16054, 269, 1, 750, Decimal('4.99'), datetime.datetime(2017, 1, 29, 8, 10, 6, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)))]

# %% [markdown]
# ### 3.1.3 Inventory

# %%
# %%sql
# select * from inventory limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# [(1, 1, 1, datetime.datetime(2017, 2, 15, 10, 9, 17, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (2, 1, 1, datetime.datetime(2017, 2, 15, 10, 9, 17, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (3, 1, 1, datetime.datetime(2017, 2, 15, 10, 9, 17, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (4, 1, 1, datetime.datetime(2017, 2, 15, 10, 9, 17, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (5, 1, 2, datetime.datetime(2017, 2, 15, 10, 9, 17, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)))]

# %% [markdown]
# ### 3.1.4 Get the movie of every payment

# %%
# %%sql
# SELECT f.title, p.amount, p.payment_date, p.customer_id
# FROM payment p
# JOIN rental r    ON ( p.rental_id = r.rental_id )
# JOIN inventory i ON ( r.inventory_id = i.inventory_id )
# JOIN film f ON ( i.film_id = f.film_id)
# limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# [('SWARM GOLD', Decimal('1.99'), datetime.datetime(2017, 1, 24, 21, 40, 19, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 269),
#  ('PACKER MADIGAN', Decimal('0.99'), datetime.datetime(2017, 1, 25, 15, 16, 50, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 269),
#  ('SOMETHING DUCK', Decimal('6.99'), datetime.datetime(2017, 1, 28, 21, 44, 14, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 269),
#  ('DRACULA CRYSTAL', Decimal('0.99'), datetime.datetime(2017, 1, 29, 0, 58, 2, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 269),
#  ('CLOSER BANG', Decimal('4.99'), datetime.datetime(2017, 1, 29, 8, 10, 6, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 269)]

# %% [markdown]
# ### 3.1.5 sum movie rental revenue

# %%
# %%sql
# SELECT f.title, sum(p.amount) as revenue
# FROM payment p
# JOIN rental r    ON ( p.rental_id = r.rental_id )
# JOIN inventory i ON ( r.inventory_id = i.inventory_id )
# JOIN film f ON ( i.film_id = f.film_id)
# GROUP BY title
# ORDER BY revenue desc
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 10 rows affected.
# [('TELEGRAPH VOYAGE', Decimal('1158.65')),
#  ('WIFE TURN', Decimal('1118.45')),
#  ('ZORRO ARK', Decimal('1073.45')),
#  ('GOODFELLAS SALUTE', Decimal('1048.45')),
#  ('SATURDAY LAMBS', Decimal('1023.60')),
#  ('TITANS JERK', Decimal('1008.55')),
#  ('TORQUE BOUND', Decimal('993.60')),
#  ('HARRY IDAHO', Decimal('978.50')),
#  ('INNOCENT USUAL', Decimal('958.70')),
#  ('HUSTLER PARTY', Decimal('953.90'))]

# %% [markdown]
# ## 3.2 Insight 2:   Top grossing cities
# - Payments amounts are in table `payment`
# - Cities are in table `cities`
# - `payment` &rarr; `customer` &rarr; `address` &rarr; `city`

# %% [markdown]
# ### 3.2.1 Get the city of each payment

# %%
# %%sql
# SELECT p.customer_id, p.rental_id, p.amount, ci.city
# FROM payment p
# JOIN customer c  ON ( p.customer_id = c.customer_id )
# JOIN address a ON ( c.address_id = a.address_id )
# JOIN city ci ON ( a.city_id = ci.city_id )
# order by p.payment_date
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 10 rows affected.
# [(130, 1, Decimal('2.99'), 'guas Lindas de Gois'),
#  (130, 1, Decimal('2.99'), 'guas Lindas de Gois'),
#  (130, 1, Decimal('2.99'), 'guas Lindas de Gois'),
#  (130, 1, Decimal('2.99'), 'guas Lindas de Gois'),
#  (130, 1, Decimal('2.99'), 'guas Lindas de Gois'),
#  (459, 2, Decimal('2.99'), 'Qomsheh'),
#  (459, 2, Decimal('2.99'), 'Qomsheh'),
#  (459, 2, Decimal('2.99'), 'Qomsheh'),
#  (459, 2, Decimal('2.99'), 'Qomsheh'),
#  (459, 2, Decimal('2.99'), 'Qomsheh')]

# %% [markdown]
# ### 3.2.2 Top grossing cities

# %%
# %%sql
# SELECT ci.city ,  sum(p.amount) as revenue
# FROM payment p
# JOIN customer c  ON ( p.customer_id = c.customer_id )
# JOIN address a ON ( c.address_id = a.address_id )
# JOIN city ci ON ( a.city_id = ci.city_id )
# group by ci.city
# order by revenue desc
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 10 rows affected.
# [('Cape Coral', Decimal('1107.75')),
#  ('Saint-Denis', Decimal('1082.70')),
#  ('Aurora', Decimal('992.50')),
#  ('Molodetno', Decimal('977.90')),
#  ('Apeldoorn', Decimal('973.05')),
#  ('Santa Brbara dOeste', Decimal('973.05')),
#  ('Qomsheh', Decimal('933.10')),
#  ('London', Decimal('902.60')),
#  ('Ourense (Orense)', Decimal('888.00')),
#  ('Bijapur', Decimal('878.05'))]

# %% [markdown]
# ## 3.3 Insight 3 : Revenue of a movie by customer city and by month

# %% [markdown]
# ### 3.3.1 Total revenue by month

# %%
# %%sql
# SELECT sum(p.amount) as revenue, EXTRACT(month FROM p.payment_date) as month
# from payment p
# group by month
# order by revenue desc
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# [(Decimal('142797.30'), 4.0),
#  (Decimal('119432.80'), 3.0),
#  (Decimal('48159.40'), 2.0),
#  (Decimal('24122.15'), 1.0),
#  (Decimal('2570.90'), 5.0)]

# %% [markdown]
# ### 3.3.2 Each movie by customer city and by month (data cube)

# %%
# %%sql
# SELECT f.title, p.amount, p.customer_id, ci.city, p.payment_date,EXTRACT(month FROM p.payment_date) as month
# FROM payment p
# JOIN rental r    ON ( p.rental_id = r.rental_id )
# JOIN inventory i ON ( r.inventory_id = i.inventory_id )
# JOIN film f ON ( i.film_id = f.film_id)
# JOIN customer c  ON ( p.customer_id = c.customer_id )
# JOIN address a ON ( c.address_id = a.address_id )
# JOIN city ci ON ( a.city_id = ci.city_id )
# order by p.payment_date
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 10 rows affected.
# [('BLANKET BEVERLY', Decimal('2.99'), 130, 'guas Lindas de Gois', datetime.datetime(2017, 1, 24, 21, 21, 56, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1.0),
#  ('BLANKET BEVERLY', Decimal('2.99'), 130, 'guas Lindas de Gois', datetime.datetime(2017, 1, 24, 21, 21, 56, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1.0),
#  ('BLANKET BEVERLY', Decimal('2.99'), 130, 'guas Lindas de Gois', datetime.datetime(2017, 1, 24, 21, 21, 56, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1.0),
#  ('BLANKET BEVERLY', Decimal('2.99'), 130, 'guas Lindas de Gois', datetime.datetime(2017, 1, 24, 21, 21, 56, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1.0),
#  ('BLANKET BEVERLY', Decimal('2.99'), 130, 'guas Lindas de Gois', datetime.datetime(2017, 1, 24, 21, 21, 56, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1.0),
#  ('FREAKY POCUS', Decimal('2.99'), 459, 'Qomsheh', datetime.datetime(2017, 1, 24, 21, 22, 59, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1.0),
#  ('FREAKY POCUS', Decimal('2.99'), 459, 'Qomsheh', datetime.datetime(2017, 1, 24, 21, 22, 59, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1.0),
#  ('FREAKY POCUS', Decimal('2.99'), 459, 'Qomsheh', datetime.datetime(2017, 1, 24, 21, 22, 59, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1.0),
#  ('FREAKY POCUS', Decimal('2.99'), 459, 'Qomsheh', datetime.datetime(2017, 1, 24, 21, 22, 59, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1.0),
#  ('FREAKY POCUS', Decimal('2.99'), 459, 'Qomsheh', datetime.datetime(2017, 1, 24, 21, 22, 59, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 1.0)]

# %% [markdown]
# ### 3.3.3 Sum of revenue of each movie by customer city and by month

# %%
# %%sql
# SELECT f.title, ci.city,EXTRACT(month FROM p.payment_date) as month, sum(p.amount) as revenue
# FROM payment p
# JOIN rental r    ON ( p.rental_id = r.rental_id )
# JOIN inventory i ON ( r.inventory_id = i.inventory_id )
# JOIN film f ON ( i.film_id = f.film_id)
# JOIN customer c  ON ( p.customer_id = c.customer_id )
# JOIN address a ON ( c.address_id = a.address_id )
# JOIN city ci ON ( a.city_id = ci.city_id )
# group by (f.title, ci.city, month)
# order by month, revenue desc
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 10 rows affected.
# [('SHOW LORD', 'Mannheim', 1.0, Decimal('59.95')),
#  ('KISSING DOLLS', 'Toulon', 1.0, Decimal('54.95')),
#  ('CASUALTIES ENCINO', 'Warren', 1.0, Decimal('54.95')),
#  ('TELEGRAPH VOYAGE', 'Naala-Porto', 1.0, Decimal('54.95')),
#  ('AMERICAN CIRCUS', 'Callao', 1.0, Decimal('54.95')),
#  ('CALIFORNIA BIRDS', 'Plock', 1.0, Decimal('49.95')),
#  ('AUTUMN CROW', 'Ashgabat', 1.0, Decimal('49.95')),
#  ('DAY UNFAITHFUL', 'Baybay', 1.0, Decimal('49.95')),
#  ('DARKO DORADO', 'Bhilwara', 1.0, Decimal('49.95')),
#  ('HEAD STRANGER', 'Xiangtan', 1.0, Decimal('49.95'))]

# %% [markdown]
# # STEP4 : Creating Facts & Dimensions

# %% [markdown]
# <img src="pagila-star.png" width="50%"/>

# %%
# %%sql
# CREATE TABLE dimDate
# (
#   date_key integer NOT NULL PRIMARY KEY,
#   date date NOT NULL,
#   year smallint NOT NULL,
#   quarter smallint NOT NULL,
#   month smallint NOT NULL,
#   day smallint NOT NULL,
#   week smallint NOT NULL,
#   is_weekend boolean
# );
#
# CREATE TABLE dimCustomer
# (
#   customer_key SERIAL PRIMARY KEY,
#   customer_id  smallint NOT NULL,
#   first_name   varchar(45) NOT NULL,
#   last_name    varchar(45) NOT NULL,
#   email        varchar(50),
#   address      varchar(50) NOT NULL,
#   address2     varchar(50),
#   district     varchar(20) NOT NULL,
#   city         varchar(50) NOT NULL,
#   country      varchar(50) NOT NULL,
#   postal_code  varchar(10),
#   phone        varchar(20) NOT NULL,
#   active       smallint NOT NULL,
#   create_date  timestamp NOT NULL,
#   start_date   date NOT NULL,
#   end_date     date NOT NULL
# );
#
# CREATE TABLE dimMovie
# (
#   movie_key          SERIAL PRIMARY KEY,
#   film_id            smallint NOT NULL,
#   title              varchar(255) NOT NULL,
#   description        text,
#   release_year       year,
#   language           varchar(20) NOT NULL,
#   original_language  varchar(20),
#   rental_duration    smallint NOT NULL,
#   length             smallint NOT NULL,
#   rating             varchar(5) NOT NULL,
#   special_features   varchar(60) NOT NULL
# );
# CREATE TABLE dimStore
# (
#   store_key           SERIAL PRIMARY KEY,
#   store_id            smallint NOT NULL,
#   address             varchar(50) NOT NULL,
#   address2            varchar(50),
#   district            varchar(20) NOT NULL,
#   city                varchar(50) NOT NULL,
#   country             varchar(50) NOT NULL,
#   postal_code         varchar(10),
#   manager_first_name  varchar(45) NOT NULL,
#   manager_last_name   varchar(45) NOT NULL,
#   start_date          date NOT NULL,
#   end_date            date NOT NULL
# );
# CREATE TABLE factSales
# (
#   sales_key        SERIAL PRIMARY KEY,
#   date_key         INT NOT NULL REFERENCES dimDate(date_key),
#   customer_key     INT NOT NULL REFERENCES dimCustomer(customer_key),
#   movie_key        INT NOT NULL REFERENCES dimMovie(movie_key),
#   store_key        INT NOT NULL REFERENCES dimStore(store_key),
#   sales_amount     decimal(5,2) NOT NULL
# );
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# (psycopg2.ProgrammingError) relation "dimdate" already exists
#  [SQL: 'CREATE TABLE dimDate\n(\n  date_key integer NOT NULL PRIMARY KEY,\n  date date NOT NULL,\n  year smallint NOT NULL,\n  quarter smallint NOT NULL,\n  month smallint NOT NULL,\n  day smallint NOT NULL,\n  week smallint NOT NULL,\n  is_weekend boolean\n);']

# %% [markdown]
# # STEP 5: ETL the data from 3NF tables to Facts & Dimension Tables

# %%
# %%sql
# INSERT INTO dimDate (date_key, date, year, quarter, month, day, week, is_weekend)
# SELECT DISTINCT(TO_CHAR(payment_date :: DATE, 'yyyyMMDD')::integer) AS date_key,
#        date(payment_date)                                           AS date,
#        EXTRACT(year FROM payment_date)                              AS year,
#        EXTRACT(quarter FROM payment_date)                           AS quarter,
#        EXTRACT(month FROM payment_date)                             AS month,
#        EXTRACT(day FROM payment_date)                               AS day,
#        EXTRACT(week FROM payment_date)                              AS week,
#        CASE WHEN EXTRACT(ISODOW FROM payment_date) IN (6, 7) THEN true ELSE false END AS is_weekend
# FROM payment;
#
#
# INSERT INTO dimCustomer (customer_key, customer_id, first_name, last_name, email, address, address2, district, city, country, postal_code, phone, active, create_date, start_date, end_date)
# SELECT c.customer_id AS customer_key,
#        c.customer_id,
#        c.first_name,
#        c.last_name,
#        c.email,
#        a.address,
#        a.address2,
#        a.district,
#        ci.city,
#        co.country,
#        a.postal_code,
#        a.phone,
#        c.active,
#        c.create_date,
#        now()         AS start_date,
#        now()         AS end_date
# FROM customer c
# JOIN address a  ON (c.address_id = a.address_id)
# JOIN city ci    ON (a.city_id = ci.city_id)
# JOIN country co ON (ci.country_id = co.country_id);
#
# INSERT INTO dimMovie (movie_key, film_id, title, description, release_year, language, original_language, rental_duration, length, rating, special_features)
# SELECT f.film_id      AS movie_key,
#        f.film_id,
#        f.title,
#        f.description,
#        f.release_year,
#        l.name         AS language,
#        orig_lang.name AS original_language,
#        f.rental_duration,
#        f.length,
#        f.rating,
#        f.special_features
# FROM film f
# JOIN language l              ON (f.language_id=l.language_id)
# LEFT JOIN language orig_lang ON (f.original_language_id = orig_lang.language_id);
#
# INSERT INTO dimStore (store_key, store_id, address, address2, district, city, country, postal_code, manager_first_name, manager_last_name, start_date, end_date)
# SELECT s.store_id    AS store_key,
#        s.store_id,
#        a.address,
#        a.address2,
#        a.district,
#        c.city,
#        co.country,
#        a.postal_code,
#        st.first_name AS manager_first_name,
#        st.last_name  AS manager_last_name,
#        now()         AS start_date,
#        now()         AS end_date
# FROM store s
# JOIN staff st   ON (s.manager_staff_id = st.staff_id)
# JOIN address a  ON (s.address_id = a.address_id)
# JOIN city c     ON (a.city_id = c.city_id)
# JOIN country co ON (c.country_id = co.country_id);
#
# INSERT INTO factSales (date_key, customer_key, movie_key, store_key, sales_amount)
# SELECT TO_CHAR(p.payment_date :: DATE, 'yyyyMMDD')::integer AS date_key ,
#        p.customer_id                                        AS customer_key,
#        i.film_id                                            AS movie_key,
#        i.store_id                                           AS store_key,
#        p.amount                                             AS sales_amount
# FROM payment p
# JOIN rental r    ON ( p.rental_id = r.rental_id )
# JOIN inventory i ON ( r.inventory_id = i.inventory_id );
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1181                         parameters,
# -> 1182                         context)
#    1183         except BaseException as e:
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     469     def do_execute(self, cursor, statement, parameters, context=None):
# --> 470         cursor.execute(statement, parameters)
#     471
#
# IntegrityError: duplicate key value violates unique constraint "dimdate_pkey"
# DETAIL:  Key (date_key)=(20170407) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-22-f4af0de3925d> in <module>()
# ----> 1 get_ipython().run_cell_magic('sql', '', "INSERT INTO dimDate (date_key, date, year, quarter, month, day, week, is_weekend)\nSELECT DISTINCT(TO_CHAR(payment_date :: DATE, 'yyyyMMDD')::integer) AS date_key,\n       date(payment_date)                                           AS date,\n       EXTRACT(year FROM payment_date)                              AS year,\n       EXTRACT(quarter FROM payment_date)                           AS quarter,\n       EXTRACT(month FROM payment_date)                             AS month,\n       EXTRACT(day FROM payment_date)                               AS day,\n       EXTRACT(week FROM payment_date)                              AS week,\n       CASE WHEN EXTRACT(ISODOW FROM payment_date) IN (6, 7) THEN true ELSE false END AS is_weekend\nFROM payment;\n\n\nINSERT INTO dimCustomer (customer_key, customer_id, first_name, last_name, email, address, address2, district, city, country, postal_code, phone, active, create_date, start_date, end_date)\nSELECT c.customer_id AS customer_key,\n       c.customer_id,\n       c.first_name,\n       c.last_name,\n       c.email,\n       a.address,\n       a.address2,\n       a.district,\n       ci.city,\n       co.country,\n       a.postal_code,\n       a.phone,\n       c.active,\n       c.create_date,\n       now()         AS start_date,\n       now()         AS end_date\nFROM customer c\nJOIN address a  ON (c.address_id = a.address_id)\nJOIN city ci    ON (a.city_id = ci.city_id)\nJOIN country co ON (ci.country_id = co.country_id);\n\nINSERT INTO dimMovie (movie_key, film_id, title, description, release_year, language, original_language, rental_duration, length, rating, special_features)\nSELECT f.film_id      AS movie_key,\n       f.film_id,\n       f.title,\n       f.description,\n       f.release_year,\n       l.name         AS language,\n       orig_lang.name AS original_language,\n       f.rental_duration,\n       f.length,\n       f.rating,\n       f.special_features\nFROM film f\nJOIN language l              ON (f.language_id=l.language_id)\nLEFT JOIN language orig_lang ON (f.original_language_id = orig_lang.language_id);\n\nINSERT INTO dimStore (store_key, store_id, address, address2, district, city, country, postal_code, manager_first_name, manager_last_name, start_date, end_date)\nSELECT s.store_id    AS store_key,\n       s.store_id,\n       a.address,\n       a.address2,\n       a.district,\n       c.city,\n       co.country,\n       a.postal_code,\n       st.first_name AS manager_first_name,\n       st.last_name  AS manager_last_name,\n       now()         AS start_date,\n       now()         AS end_date\nFROM store s\nJOIN staff st   ON (s.manager_staff_id = st.staff_id)\nJOIN address a  ON (s.address_id = a.address_id)\nJOIN city c     ON (a.city_id = c.city_id)\nJOIN country co ON (c.country_id = co.country_id);\n\nINSERT INTO factSales (date_key, customer_key, movie_key, store_key, sales_amount)\nSELECT TO_CHAR(p.payment_date :: DATE, 'yyyyMMDD')::integer AS date_key ,\n       p.customer_id                                        AS customer_key,\n       i.film_id                                            AS movie_key,\n       i.store_id                                           AS store_key,\n       p.amount                                             AS sales_amount\nFROM payment p\nJOIN rental r    ON ( p.rental_id = r.rental_id )\nJOIN inventory i ON ( r.inventory_id = i.inventory_id );")
#
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2165             magic_arg_s = self.var_expand(line, stack_depth)
#    2166             with self.builtin_trap:
# -> 2167                 result = fn(magic_arg_s, cell)
#    2168             return result
#    2169
#
# <decorator-gen-126> in execute(self, line, cell, local_ns)
#
# /opt/conda/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# <decorator-gen-125> in execute(self, line, cell, local_ns)
#
# /opt/conda/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /opt/conda/lib/python3.6/site-packages/sql/magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# /opt/conda/lib/python3.6/site-packages/sql/run.py in run(conn, sql, config, user_namespace)
#     338             else:
#     339                 txt = sqlalchemy.sql.text(statement)
# --> 340                 result = conn.session.execute(txt, user_namespace)
#     341             _commit(conn=conn, config=config)
#     342             if result and config.feedback:
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in execute(self, object, *multiparams, **params)
#     943             raise exc.ObjectNotExecutableError(object)
#     944         else:
# --> 945             return meth(self, multiparams, params)
#     946
#     947     def _execute_function(self, func, multiparams, params):
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     261     def _execute_on_connection(self, connection, multiparams, params):
#     262         if self.supports_execution:
# --> 263             return connection._execute_clauseelement(self, multiparams, params)
#     264         else:
#     265             raise exc.ObjectNotExecutableError(self)
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1051             compiled_sql,
#    1052             distilled_params,
# -> 1053             compiled_sql, distilled_params
#    1054         )
#    1055         if self._has_events or self.engine._has_events:
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1187                 parameters,
#    1188                 cursor,
# -> 1189                 context)
#    1190
#    1191         if self._has_events or self.engine._has_events:
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1400                 util.raise_from_cause(
#    1401                     sqlalchemy_exception,
# -> 1402                     exc_info
#    1403                 )
#    1404             else:
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     201     exc_type, exc_value, exc_tb = exc_info
#     202     cause = exc_value if exc_value is not exception else None
# --> 203     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     204
#     205 if py3k:
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     184             value.__cause__ = cause
#     185         if value.__traceback__ is not tb:
# --> 186             raise value.with_traceback(tb)
#     187         raise value
#     188
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1180                         statement,
#    1181                         parameters,
# -> 1182                         context)
#    1183         except BaseException as e:
#    1184             self._handle_dbapi_exception(
#
# /opt/conda/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     468
#     469     def do_execute(self, cursor, statement, parameters, context=None):
# --> 470         cursor.execute(statement, parameters)
#     471
#     472     def do_execute_no_params(self, cursor, statement, context=None):
#
# IntegrityError: (psycopg2.IntegrityError) duplicate key value violates unique constraint "dimdate_pkey"
# DETAIL:  Key (date_key)=(20170407) already exists.
#  [SQL: "INSERT INTO dimDate (date_key, date, year, quarter, month, day, week, is_weekend)\nSELECT DISTINCT(TO_CHAR(payment_date :: DATE, 'yyyyMMDD')::integer) AS date_key,\n       date(payment_date)                                           AS date,\n       EXTRACT(year FROM payment_date)                              AS year,\n       EXTRACT(quarter FROM payment_date)                           AS quarter,\n       EXTRACT(month FROM payment_date)                             AS month,\n       EXTRACT(day FROM payment_date)                               AS day,\n       EXTRACT(week FROM payment_date)                              AS week,\n       CASE WHEN EXTRACT(ISODOW FROM payment_date) IN (6, 7) THEN true ELSE false END AS is_weekend\nFROM payment;"]

# %% [markdown]
# # STEP 6: Repeat the computation from the facts & dimension table

# %% [markdown]
# ## 6.1 Facts Table has all the needed dimensions, no need for deep joins

# %%
# %%time
# %%sql
SELECT movie_key, date_key, customer_key, sales_amount
FROM factSales 
limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# CPU times: user 0 ns, sys: 3.32 ms, total: 3.32 ms
# Wall time: 5.11 ms
# [(870, 20170124, 269, Decimal('1.99')),
#  (651, 20170125, 269, Decimal('0.99')),
#  (818, 20170128, 269, Decimal('6.99')),
#  (249, 20170129, 269, Decimal('0.99')),
#  (159, 20170129, 269, Decimal('4.99'))]

# %% [markdown]
# ## 6.2 Join fact table with dimensions to replace keys with attributes

# %%
# %%time
# %%sql
SELECT dimMovie.title, dimDate.month, dimCustomer.city, sales_amount
FROM factSales 
JOIN dimMovie on (dimMovie.movie_key = factSales.movie_key)
JOIN dimDate on (dimDate.date_key = factSales.date_key)
JOIN dimCustomer on (dimCustomer.customer_key = factSales.customer_key)
limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# CPU times: user 4.53 ms, sys: 60 µs, total: 4.59 ms
# Wall time: 7.54 ms
# [('SWARM GOLD', 1, 'Salinas', Decimal('1.99')),
#  ('PACKER MADIGAN', 1, 'Salinas', Decimal('0.99')),
#  ('SOMETHING DUCK', 1, 'Salinas', Decimal('6.99')),
#  ('DRACULA CRYSTAL', 1, 'Salinas', Decimal('0.99')),
#  ('CLOSER BANG', 1, 'Salinas', Decimal('4.99'))]

# %%
# %%time
# %%sql
SELECT dimMovie.title, dimDate.month, dimCustomer.city, sum(sales_amount) as revenue
FROM factSales 
JOIN dimMovie    on (dimMovie.movie_key      = factSales.movie_key)
JOIN dimDate     on (dimDate.date_key         = factSales.date_key)
JOIN dimCustomer on (dimCustomer.customer_key = factSales.customer_key)
group by (dimMovie.title, dimDate.month, dimCustomer.city)
order by dimMovie.title, dimDate.month, dimCustomer.city, revenue desc;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 15992 rows affected.
# CPU times: user 36 ms, sys: 12.1 ms, total: 48.1 ms
# Wall time: 293 ms
# [('ACADEMY DINOSAUR', 1, 'Celaya', Decimal('3.96')),
#  ('ACADEMY DINOSAUR', 1, 'Cianjur', Decimal('7.96')),
#  ('ACADEMY DINOSAUR', 2, 'San Lorenzo', Decimal('3.96')),
#  ('ACADEMY DINOSAUR', 2, 'Sullana', Decimal('7.96')),
#  ('ACADEMY DINOSAUR', 2, 'Udaipur', Decimal('3.96')),
#  ('ACADEMY DINOSAUR', 3, 'Almirante Brown', Decimal('7.96')),
#  ('ACADEMY DINOSAUR', 3, 'Goinia', Decimal('3.96')),
#  ('ACADEMY DINOSAUR', 3, 'Kaliningrad', Decimal('3.96')),
#  ('ACADEMY DINOSAUR', 3, 'Kurashiki', Decimal('3.96')),
#  ('ACADEMY DINOSAUR', 3, 'Livorno', Decimal('3.96')),
#  ('ACADEMY DINOSAUR', 3, 'Nukualofa', Decimal('3.96')),
#  ('ACADEMY DINOSAUR', 3, 'Rajkot', Decimal('15.96')),
#  ('ACADEMY DINOSAUR', 3, 'Sivas', Decimal('15.96')),
#  ('ACADEMY DINOSAUR', 3, 'Tabriz', Decimal('15.96')),
#  ('ACADEMY DINOSAUR', 4, 'Charlotte Amalie', Decimal('3.96')),
#  ('ACADEMY DINOSAUR', 4, 'Hamilton', Decimal('3.96')),
#  ('ACADEMY DINOSAUR', 4, 'Jos Azueta', Decimal('7.96')),
#  ('ACADEMY DINOSAUR', 4, 'Lipetsk', Decimal('3.96')),
#  ('ACADEMY DINOSAUR', 4, 'London', Decimal('3.96')),
#  ('ACADEMY DINOSAUR', 4, 'Pjatigorsk', Decimal('7.96')),
#  ('ACADEMY DINOSAUR', 4, 'Sucre', Decimal('3.96')),
#  ('ACADEMY DINOSAUR', 4, 'Tel Aviv-Jaffa', Decimal('3.96')),
#  ('ACADEMY DINOSAUR', 4, 'Vila Velha', Decimal('3.96')),
#  ('ACE GOLDFINGER', 3, 'Binzhou', Decimal('35.96')),
#  ('ACE GOLDFINGER', 3, 'Kumbakonam', Decimal('19.96')),
#  ('ACE GOLDFINGER', 3, 'Pereira', Decimal('35.96')),
#  ('ACE GOLDFINGER', 3, 'Touliu', Decimal('39.96')),
#  ('ACE GOLDFINGER', 4, 'Simferopol', Decimal('39.96')),
#  ('ACE GOLDFINGER', 4, 'Soshanguve', Decimal('19.96')),
#  ('ACE GOLDFINGER', 5, 'Balikesir', Decimal('19.96')),
#  ('ADAPTATION HOLES', 1, 'Shikarpur', Decimal('11.96')),
#  ('ADAPTATION HOLES', 2, 'Jelets', Decimal('11.96')),
#  ('ADAPTATION HOLES', 3, 'Cayenne', Decimal('11.96')),
#  ('ADAPTATION HOLES', 3, 'Coacalco de Berriozbal', Decimal('11.96')),
#  ('ADAPTATION HOLES', 3, 'Salinas', Decimal('11.96')),
#  ('ADAPTATION HOLES', 3, 'Santa Brbara dOeste', Decimal('11.96')),
#  ('ADAPTATION HOLES', 3, 'Sasebo', Decimal('19.96')),
#  ('ADAPTATION HOLES', 3, 'al-Qatif', Decimal('11.96')),
#  ('ADAPTATION HOLES', 4, 'Jodhpur', Decimal('11.96')),
#  ('ADAPTATION HOLES', 4, 'Miraj', Decimal('11.96')),
#  ('ADAPTATION HOLES', 4, 'Ogbomosho', Decimal('11.96')),
#  ('ADAPTATION HOLES', 4, 'Urawa', Decimal('11.96')),
#  ('AFFAIR PREJUDICE', 1, 'Hidalgo', Decimal('15.96')),
#  ('AFFAIR PREJUDICE', 1, 'Tuguegarao', Decimal('15.96')),
#  ('AFFAIR PREJUDICE', 2, 'Changzhou', Decimal('11.96')),
#  ('AFFAIR PREJUDICE', 2, 'Crdoba', Decimal('11.96')),
#  ('AFFAIR PREJUDICE', 3, 'Aparecida de Goinia', Decimal('11.96')),
#  ('AFFAIR PREJUDICE', 3, 'Atinsk', Decimal('11.96')),
#  ('AFFAIR PREJUDICE', 3, 'Avellaneda', Decimal('27.96')),
#  ('AFFAIR PREJUDICE', 3, 'Caracas', Decimal('27.96')),
#  ('AFFAIR PREJUDICE', 3, 'Laiwu', Decimal('11.96')),
#  ('AFFAIR PREJUDICE', 3, 'Rancagua', Decimal('11.96')),
#  ('AFFAIR PREJUDICE', 4, 'Chiayi', Decimal('19.96')),
#  ('AFFAIR PREJUDICE', 4, 'Ciomas', Decimal('23.96')),
#  ('AFFAIR PREJUDICE', 4, 'Lublin', Decimal('11.96')),
#  ('AFFAIR PREJUDICE', 4, 'Malm', Decimal('23.96')),
#  ('AFFAIR PREJUDICE', 4, 'Palghat (Palakkad)', Decimal('11.96')),
#  ('AFFAIR PREJUDICE', 4, 'Qomsheh', Decimal('11.96')),
#  ('AFFAIR PREJUDICE', 4, 'Saint-Denis', Decimal('15.96')),
#  ('AFFAIR PREJUDICE', 4, 'San Felipe de Puerto Plata', Decimal('19.96')),
#  ('AFFAIR PREJUDICE', 4, 'Sirjan', Decimal('11.96')),
#  ('AFFAIR PREJUDICE', 4, 'Sokoto', Decimal('19.96')),
#  ('AFFAIR PREJUDICE', 4, 'Tiefa', Decimal('11.96')),
#  ('AFFAIR PREJUDICE', 4, 's-Hertogenbosch', Decimal('11.96')),
#  ('AFFAIR PREJUDICE', 5, 'Caracas', Decimal('11.96')),
#  ('AFRICAN EGG', 1, 'Ivanovo', Decimal('15.96')),
#  ('AFRICAN EGG', 2, 'Okayama', Decimal('15.96')),
#  ('AFRICAN EGG', 2, 'Richmond Hill', Decimal('19.96')),
#  ('AFRICAN EGG', 3, 'Rampur', Decimal('15.96')),
#  ('AFRICAN EGG', 3, 'Smolensk', Decimal('19.96')),
#  ('AFRICAN EGG', 3, 'Tokat', Decimal('11.96')),
#  ('AFRICAN EGG', 4, 'Jedda', Decimal('19.96')),
#  ('AFRICAN EGG', 4, 'Jhansi', Decimal('11.96')),
#  ('AFRICAN EGG', 4, 'Kitwe', Decimal('19.96')),
#  ('AFRICAN EGG', 4, 'Salzburg', Decimal('23.96')),
#  ('AFRICAN EGG', 4, 'York', Decimal('19.96')),
#  ('AFRICAN EGG', 5, 'al-Manama', Decimal('11.96')),
#  ('AGENT TRUMAN', 1, 'Coatzacoalcos', Decimal('35.96')),
#  ('AGENT TRUMAN', 1, 'Izumisano', Decimal('23.96')),
#  ('AGENT TRUMAN', 2, 'Antofagasta', Decimal('15.96')),
#  ('AGENT TRUMAN', 2, 'Moscow', Decimal('35.96')),
#  ('AGENT TRUMAN', 2, 'Taizz', Decimal('27.96')),
#  ('AGENT TRUMAN', 3, 'Bhilwara', Decimal('35.96')),
#  ('AGENT TRUMAN', 3, 'Chisinau', Decimal('19.96')),
#  ('AGENT TRUMAN', 3, 'Citrus Heights', Decimal('27.96')),
#  ('AGENT TRUMAN', 3, 'Emeishan', Decimal('15.96')),
#  ('AGENT TRUMAN', 3, 'Luzinia', Decimal('15.96')),
#  ('AGENT TRUMAN', 3, 'Mogiljov', Decimal('27.96')),
#  ('AGENT TRUMAN', 3, 'Omdurman', Decimal('31.96')),
#  ('AGENT TRUMAN', 3, 'Sunnyvale', Decimal('19.96')),
#  ('AGENT TRUMAN', 3, 'Usak', Decimal('31.96')),
#  ('AGENT TRUMAN', 4, 'Aurora', Decimal('19.96')),
#  ('AGENT TRUMAN', 4, 'Huixquilucan', Decimal('19.96')),
#  ('AGENT TRUMAN', 4, 'Matsue', Decimal('23.96')),
#  ('AGENT TRUMAN', 4, 'Nantou', Decimal('11.96')),
#  ('AGENT TRUMAN', 4, 'Pontianak', Decimal('31.96')),
#  ('AGENT TRUMAN', 4, 'Quilmes', Decimal('11.96')),
#  ('AGENT TRUMAN', 4, 'Tafuna', Decimal('19.96')),
#  ('AIRPLANE SIERRA', 2, 'Cavite', Decimal('31.96')),
#  ('AIRPLANE SIERRA', 2, 'Lubumbashi', Decimal('19.96')),
#  ('AIRPLANE SIERRA', 3, 'Ibirit', Decimal('19.96')),
#  ('AIRPLANE SIERRA', 3, 'Iwakuni', Decimal('19.96')),
#  ('AIRPLANE SIERRA', 3, 'Johannesburg', Decimal('31.96')),
#  ('AIRPLANE SIERRA', 3, 'Jurez', Decimal('19.96')),
#  ('AIRPLANE SIERRA', 3, 'Mahajanga', Decimal('23.96')),
#  ('AIRPLANE SIERRA', 3, 's-Hertogenbosch', Decimal('19.96')),
#  ('AIRPLANE SIERRA', 4, 'Bhusawal', Decimal('19.96')),
#  ('AIRPLANE SIERRA', 4, 'Kuwana', Decimal('19.96')),
#  ('AIRPLANE SIERRA', 4, 'Salamanca', Decimal('23.96')),
#  ('AIRPLANE SIERRA', 4, 'Sincelejo', Decimal('19.96')),
#  ('AIRPLANE SIERRA', 4, 'Tsuyama', Decimal('19.96')),
#  ('AIRPLANE SIERRA', 4, 'Yuncheng', Decimal('19.96')),
#  ('AIRPLANE SIERRA', 4, 'Zalantun', Decimal('19.96')),
#  ('AIRPORT POLLOCK', 1, 'Okinawa', Decimal('23.96')),
#  ('AIRPORT POLLOCK', 1, 'Pemalang', Decimal('19.96')),
#  ('AIRPORT POLLOCK', 1, 'Taguig', Decimal('19.96')),
#  ('AIRPORT POLLOCK', 2, 'Molodetno', Decimal('23.96')),
#  ('AIRPORT POLLOCK', 2, 'Portoviejo', Decimal('27.96')),
#  ('AIRPORT POLLOCK', 2, 'Vaduz', Decimal('19.96')),
#  ('AIRPORT POLLOCK', 3, 'Augusta-Richmond County', Decimal('19.96')),
#  ('AIRPORT POLLOCK', 3, 'Lilongwe', Decimal('31.96')),
#  ('AIRPORT POLLOCK', 3, 'Lublin', Decimal('27.96')),
#  ('AIRPORT POLLOCK', 3, 'Peoria', Decimal('23.96')),
#  ('AIRPORT POLLOCK', 3, 'Yangor', Decimal('23.96')),
#  ('AIRPORT POLLOCK', 4, 'Bamenda', Decimal('23.96')),
#  ('AIRPORT POLLOCK', 4, 'Dhaka', Decimal('19.96')),
#  ('AIRPORT POLLOCK', 4, 'Erlangen', Decimal('23.96')),
#  ('AIRPORT POLLOCK', 4, 'Fukuyama', Decimal('19.96')),
#  ('AIRPORT POLLOCK', 4, 'Palghat (Palakkad)', Decimal('19.96')),
#  ('AIRPORT POLLOCK', 4, 'San Juan Bautista Tuxtepec', Decimal('19.96')),
#  ('AIRPORT POLLOCK', 4, 'Sanaa', Decimal('19.96')),
#  ('ALABAMA DEVIL', 3, 'Greensboro', Decimal('23.96')),
#  ('ALABAMA DEVIL', 3, 'Halifax', Decimal('31.96')),
#  ('ALABAMA DEVIL', 3, 'Otsu', Decimal('35.96')),
#  ('ALABAMA DEVIL', 3, 'Sunnyvale', Decimal('11.96')),
#  ('ALABAMA DEVIL', 3, 'Zaoyang', Decimal('23.96')),
#  ('ALABAMA DEVIL', 4, 'Arlington', Decimal('35.96')),
#  ('ALABAMA DEVIL', 4, 'Asuncin', Decimal('23.96')),
#  ('ALABAMA DEVIL', 4, 'Changhwa', Decimal('19.96')),
#  ('ALABAMA DEVIL', 4, 'Eskisehir', Decimal('11.96')),
#  ('ALABAMA DEVIL', 4, 'Kanazawa', Decimal('19.96')),
#  ('ALABAMA DEVIL', 4, 'Mit Ghamr', Decimal('11.96')),
#  ('ALABAMA DEVIL', 4, 'Probolinggo', Decimal('35.96')),
#  ('ALADDIN CALENDAR', 2, 'Kaduna', Decimal('19.96')),
#  ('ALADDIN CALENDAR', 2, 'Kisumu', Decimal('19.96')),
#  ('ALADDIN CALENDAR', 2, 'La Plata', Decimal('19.96')),
#  ('ALADDIN CALENDAR', 2, 'Olomouc', Decimal('19.96')),
#  ('ALADDIN CALENDAR', 3, 'Adoni', Decimal('27.96')),
#  ('ALADDIN CALENDAR', 3, 'Balaiha', Decimal('27.96')),
#  ('ALADDIN CALENDAR', 3, 'Coacalco de Berriozbal', Decimal('19.96')),
#  ('ALADDIN CALENDAR', 3, 'Deba Habe', Decimal('19.96')),
#  ('ALADDIN CALENDAR', 3, 'Dos Quebradas', Decimal('19.96')),
#  ('ALADDIN CALENDAR', 3, 'Halisahar', Decimal('19.96')),
#  ('ALADDIN CALENDAR', 3, 'Mwanza', Decimal('19.96')),
#  ('ALADDIN CALENDAR', 3, 'Ranchi', Decimal('19.96')),
#  ('ALADDIN CALENDAR', 3, 'Sogamoso', Decimal('31.96')),
#  ('ALADDIN CALENDAR', 3, 'Zalantun', Decimal('19.96')),
#  ('ALADDIN CALENDAR', 4, 'Effon-Alaiye', Decimal('19.96')),
#  ('ALADDIN CALENDAR', 4, 'Esfahan', Decimal('19.96')),
#  ('ALADDIN CALENDAR', 4, 'Gulbarga', Decimal('31.96')),
#  ('ALADDIN CALENDAR', 4, 'Hodeida', Decimal('19.96')),
#  ('ALADDIN CALENDAR', 4, 'Izumisano', Decimal('31.96')),
#  ('ALADDIN CALENDAR', 4, 'Monclova', Decimal('19.96')),
#  ('ALADDIN CALENDAR', 4, 'Okinawa', Decimal('19.96')),
#  ('ALADDIN CALENDAR', 4, 'Stockport', Decimal('23.96')),
#  ('ALADDIN CALENDAR', 4, 'Valencia', Decimal('31.96')),
#  ('ALAMO VIDEOTAPE', 1, 'Arecibo', Decimal('3.96')),
#  ('ALAMO VIDEOTAPE', 1, 'Yuzhou', Decimal('15.96')),
#  ('ALAMO VIDEOTAPE', 2, 'Meixian', Decimal('3.96')),
#  ('ALAMO VIDEOTAPE', 2, 'Rio Claro', Decimal('3.96')),
#  ('ALAMO VIDEOTAPE', 2, 'Tarlac', Decimal('7.96')),
#  ('ALAMO VIDEOTAPE', 3, 'Baicheng', Decimal('7.96')),
#  ('ALAMO VIDEOTAPE', 3, 'Bat Yam', Decimal('3.96')),
#  ('ALAMO VIDEOTAPE', 3, 'Ife', Decimal('3.96')),
#  ('ALAMO VIDEOTAPE', 3, 'Jinchang', Decimal('7.96')),
#  ('ALAMO VIDEOTAPE', 3, 'Myingyan', Decimal('3.96')),
#  ('ALAMO VIDEOTAPE', 3, 'Papeete', Decimal('7.96')),
#  ('ALAMO VIDEOTAPE', 3, 'Pudukkottai', Decimal('15.96')),
#  ('ALAMO VIDEOTAPE', 3, 'Stara Zagora', Decimal('7.96')),
#  ('ALAMO VIDEOTAPE', 3, 'Tanauan', Decimal('3.96')),
#  ('ALAMO VIDEOTAPE', 4, 'Berhampore (Baharampur)', Decimal('3.96')),
#  ('ALAMO VIDEOTAPE', 4, 'Duisburg', Decimal('3.96')),
#  ('ALAMO VIDEOTAPE', 4, 'Emmen', Decimal('3.96')),
#  ('ALAMO VIDEOTAPE', 4, 'Grand Prairie', Decimal('7.96')),
#  ('ALAMO VIDEOTAPE', 4, 'Idfu', Decimal('3.96')),
#  ('ALAMO VIDEOTAPE', 4, 'Lapu-Lapu', Decimal('7.92')),
#  ('ALAMO VIDEOTAPE', 4, 'Owo', Decimal('3.96')),
#  ('ALAMO VIDEOTAPE', 4, 'Pemalang', Decimal('3.96')),
#  ('ALAMO VIDEOTAPE', 4, 'Zeleznogorsk', Decimal('3.96')),
#  ('ALASKA PHANTOM', 1, 'Nezahualcyotl', Decimal('3.96')),
#  ('ALASKA PHANTOM', 1, 'Zhezqazghan', Decimal('11.96')),
#  ('ALASKA PHANTOM', 2, 'Braslia', Decimal('11.96')),
#  ('ALASKA PHANTOM', 2, 'Maring', Decimal('3.96')),
#  ('ALASKA PHANTOM', 2, 'Sterling Heights', Decimal('7.96')),
#  ('ALASKA PHANTOM', 2, 'Touliu', Decimal('3.96')),
#  ('ALASKA PHANTOM', 2, 'al-Qadarif', Decimal('3.96')),
#  ('ALASKA PHANTOM', 3, 'Dhule (Dhulia)', Decimal('11.96')),
#  ('ALASKA PHANTOM', 3, 'Laohekou', Decimal('7.96')),
#  ('ALASKA PHANTOM', 3, 'Nabereznyje Telny', Decimal('3.96')),
#  ('ALASKA PHANTOM', 3, 'Nantou', Decimal('3.96')),
#  ('ALASKA PHANTOM', 3, 'Peoria', Decimal('15.96')),
#  ('ALASKA PHANTOM', 3, 'Saint Louis', Decimal('3.96')),
#  ('ALASKA PHANTOM', 3, 'Szkesfehrvr', Decimal('7.96')),
#  ('ALASKA PHANTOM', 3, 'Zhezqazghan', Decimal('3.96')),
#  ('ALASKA PHANTOM', 4, 'Baicheng', Decimal('3.96')),
#  ('ALASKA PHANTOM', 4, 'Bhilwara', Decimal('15.96')),
#  ('ALASKA PHANTOM', 4, 'Dhule (Dhulia)', Decimal('3.96')),
#  ('ALASKA PHANTOM', 4, 'Lhokseumawe', Decimal('7.96')),
#  ('ALASKA PHANTOM', 4, 'Ljubertsy', Decimal('3.96')),
#  ('ALASKA PHANTOM', 4, 'Mandi Bahauddin', Decimal('3.96')),
#  ('ALASKA PHANTOM', 4, 'Niznekamsk', Decimal('11.96')),
#  ('ALASKA PHANTOM', 4, 'Omdurman', Decimal('3.96')),
#  ('ALASKA PHANTOM', 4, 'Tiefa', Decimal('3.96')),
#  ('ALASKA PHANTOM', 4, 'Xiangtan', Decimal('7.96')),
#  ('ALASKA PHANTOM', 4, 'al-Hawiya', Decimal('3.96')),
#  ('ALI FOREVER', 3, 'Esfahan', Decimal('23.96')),
#  ('ALI FOREVER', 3, 'Lubumbashi', Decimal('19.96')),
#  ('ALI FOREVER', 3, 'Ourense (Orense)', Decimal('39.96')),
#  ('ALI FOREVER', 3, 'Sharja', Decimal('19.96')),
#  ('ALI FOREVER', 4, 'Cuauhtmoc', Decimal('31.96')),
#  ('ALI FOREVER', 4, 'Jakarta', Decimal('19.96')),
#  ('ALI FOREVER', 4, 'Maikop', Decimal('23.96')),
#  ('ALI FOREVER', 4, 'Vaduz', Decimal('19.96')),
#  ('ALI FOREVER', 5, 'Huixquilucan', Decimal('19.96')),
#  ('ALIEN CENTER', 1, 'Caracas', Decimal('11.96')),
#  ('ALIEN CENTER', 1, 'Escobar', Decimal('11.96')),
#  ('ALIEN CENTER', 2, 'Baiyin', Decimal('11.96')),
#  ('ALIEN CENTER', 2, 'Lengshuijiang', Decimal('11.96')),
#  ('ALIEN CENTER', 2, 'Rancagua', Decimal('19.96')),
#  ('ALIEN CENTER', 3, 'Bag', Decimal('11.96')),
#  ('ALIEN CENTER', 3, 'Hsichuh', Decimal('11.96')),
#  ('ALIEN CENTER', 3, 'Huejutla de Reyes', Decimal('11.96')),
#  ('ALIEN CENTER', 3, 'Kragujevac', Decimal('11.96')),
#  ('ALIEN CENTER', 3, 'Memphis', Decimal('27.96')),
#  ('ALIEN CENTER', 3, 'Nagareyama', Decimal('11.96')),
#  ('ALIEN CENTER', 3, 'San Felipe de Puerto Plata', Decimal('23.96')),
#  ('ALIEN CENTER', 3, 'Sanya', Decimal('19.96')),
#  ('ALIEN CENTER', 3, 'Songkhla', Decimal('11.96')),
#  ('ALIEN CENTER', 4, 'Cuman', Decimal('11.96')),
#  ('ALIEN CENTER', 4, 'El Fuerte', Decimal('19.96')),
#  ('ALIEN CENTER', 4, 'Emeishan', Decimal('27.96')),
#  ('ALIEN CENTER', 4, 'Juazeiro do Norte', Decimal('15.96')),
#  ('ALIEN CENTER', 4, 'Richmond Hill', Decimal('11.96')),
#  ('ALIEN CENTER', 4, 'Shahr-e Kord', Decimal('11.96')),
#  ('ALIEN CENTER', 4, 'Xiangfan', Decimal('27.96')),
#  ('ALIEN CENTER', 4, 'Zhezqazghan', Decimal('23.96')),
#  ('ALLEY EVOLUTION', 1, 'Najafabad', Decimal('23.96')),
#  ('ALLEY EVOLUTION', 2, 'Lancaster', Decimal('11.96')),
#  ('ALLEY EVOLUTION', 2, 'Mexicali', Decimal('27.96')),
#  ('ALLEY EVOLUTION', 3, 'Aden', Decimal('19.96')),
#  ('ALLEY EVOLUTION', 3, 'Jos Azueta', Decimal('11.96')),
#  ('ALLEY EVOLUTION', 3, 'Kalisz', Decimal('11.96')),
#  ('ALLEY EVOLUTION', 3, 'Ponce', Decimal('11.96')),
#  ('ALLEY EVOLUTION', 3, 'Shahr-e Kord', Decimal('11.96')),
#  ('ALLEY EVOLUTION', 3, 'Tuguegarao', Decimal('11.96')),
#  ('ALLEY EVOLUTION', 4, 'Esfahan', Decimal('11.96')),
#  ('ALLEY EVOLUTION', 4, 'NDjamna', Decimal('11.96')),
#  ('ALLEY EVOLUTION', 4, 'Shikarpur', Decimal('11.96')),
#  ('ALLEY EVOLUTION', 4, 'Tonghae', Decimal('19.96')),
#  ('ALLEY EVOLUTION', 4, 'Tsaotun', Decimal('11.96')),
#  ('ALONE TRIP', 1, 'Arak', Decimal('3.96')),
#  ('ALONE TRIP', 2, 'Almirante Brown', Decimal('3.96')),
#  ('ALONE TRIP', 2, 'Tuguegarao', Decimal('15.96')),
#  ('ALONE TRIP', 3, 'Kamjanets-Podilskyi', Decimal('15.96')),
#  ('ALONE TRIP', 3, 'Lungtan', Decimal('11.96')),
#  ('ALONE TRIP', 3, 'NDjamna', Decimal('3.96')),
#  ('ALONE TRIP', 3, 'Sincelejo', Decimal('11.96')),
#  ('ALONE TRIP', 3, 'Sousse', Decimal('19.96')),
#  ('ALONE TRIP', 3, 'Sterling Heights', Decimal('19.96')),
#  ('ALONE TRIP', 3, 'Tarsus', Decimal('11.96')),
#  ('ALONE TRIP', 3, 'Vinh', Decimal('7.96')),
#  ('ALONE TRIP', 4, 'Arecibo', Decimal('7.96')),
#  ('ALONE TRIP', 4, 'Cabuyao', Decimal('7.96')),
#  ('ALONE TRIP', 4, 'Hami', Decimal('27.96')),
#  ('ALONE TRIP', 4, 'Huixquilucan', Decimal('19.96')),
#  ('ALONE TRIP', 4, 'Mwanza', Decimal('27.96')),
#  ('ALONE TRIP', 4, 'Syktyvkar', Decimal('27.96')),
#  ('ALONE TRIP', 5, 'Tanza', Decimal('3.96')),
#  ('ALTER VICTORY', 1, 'Ezhou', Decimal('3.96')),
#  ('ALTER VICTORY', 1, 'Vinh', Decimal('3.96')),
#  ('ALTER VICTORY', 2, 'Charlotte Amalie', Decimal('3.96')),
#  ('ALTER VICTORY', 2, 'Cianjur', Decimal('3.96')),
#  ('ALTER VICTORY', 2, 'Purnea (Purnia)', Decimal('3.96')),
#  ('ALTER VICTORY', 3, 'Alessandria', Decimal('3.96')),
#  ('ALTER VICTORY', 3, 'Bijapur', Decimal('3.96')),
#  ('ALTER VICTORY', 3, 'Kamyin', Decimal('3.96')),
#  ('ALTER VICTORY', 3, 'Korolev', Decimal('3.96')),
#  ('ALTER VICTORY', 3, 'Meixian', Decimal('3.96')),
#  ('ALTER VICTORY', 3, 'Tongliao', Decimal('7.96')),
#  ('ALTER VICTORY', 4, 'Addis Abeba', Decimal('7.96')),
#  ('ALTER VICTORY', 4, 'Avellaneda', Decimal('3.96')),
#  ('ALTER VICTORY', 4, 'Bandar Seri Begawan', Decimal('3.96')),
#  ('ALTER VICTORY', 4, 'Boksburg', Decimal('3.96')),
#  ('ALTER VICTORY', 4, 'Kitwe', Decimal('15.96')),
#  ('ALTER VICTORY', 4, 'Nantou', Decimal('3.96')),
#  ('ALTER VICTORY', 4, 'Shaoguan', Decimal('15.96')),
#  ('ALTER VICTORY', 4, 'Shimonoseki', Decimal('3.96')),
#  ('ALTER VICTORY', 4, 'Sirjan', Decimal('15.96')),
#  ('ALTER VICTORY', 4, 'Tiefa', Decimal('3.96')),
#  ('ALTER VICTORY', 4, 'Urawa', Decimal('3.96')),
#  ('AMADEUS HOLY', 1, 'La Plata', Decimal('3.96')),
#  ('AMADEUS HOLY', 2, 'Denizli', Decimal('3.96')),
#  ('AMADEUS HOLY', 2, 'Jakarta', Decimal('3.96')),
#  ('AMADEUS HOLY', 2, 'Kurashiki', Decimal('3.96')),
#  ('AMADEUS HOLY', 2, 'Myingyan', Decimal('3.96')),
#  ('AMADEUS HOLY', 3, 'Araatuba', Decimal('3.96')),
#  ('AMADEUS HOLY', 3, 'Citt del Vaticano', Decimal('7.96')),
#  ('AMADEUS HOLY', 3, 'Joliet', Decimal('15.96')),
#  ('AMADEUS HOLY', 3, 'Laredo', Decimal('3.96')),
#  ('AMADEUS HOLY', 3, 'Matamoros', Decimal('3.96')),
#  ('AMADEUS HOLY', 3, 'Shubra al-Khayma', Decimal('15.96')),
#  ('AMADEUS HOLY', 3, 'Vila Velha', Decimal('3.96')),
#  ('AMADEUS HOLY', 4, 'Arak', Decimal('3.96')),
#  ('AMADEUS HOLY', 4, 'Bilbays', Decimal('7.96')),
#  ('AMADEUS HOLY', 4, 'Hohhot', Decimal('7.96')),
#  ('AMADEUS HOLY', 4, 'Jining', Decimal('3.96')),
#  ('AMADEUS HOLY', 4, 'Nabereznyje Telny', Decimal('3.96')),
#  ('AMADEUS HOLY', 4, 'Pjatigorsk', Decimal('3.96')),
#  ('AMADEUS HOLY', 4, 'Poos de Caldas', Decimal('15.96')),
#  ('AMADEUS HOLY', 4, 'Warren', Decimal('7.96')),
#  ('AMADEUS HOLY', 5, 'London', Decimal('3.96')),
#  ('AMELIE HELLFIGHTERS', 2, 'Acua', Decimal('19.96')),
#  ('AMELIE HELLFIGHTERS', 2, 'Ipoh', Decimal('23.96')),
#  ('AMELIE HELLFIGHTERS', 3, 'Anpolis', Decimal('19.96')),
#  ('AMELIE HELLFIGHTERS', 3, 'Sterling Heights', Decimal('19.96')),
#  ('AMELIE HELLFIGHTERS', 3, 'Tonghae', Decimal('35.96')),
#  ('AMELIE HELLFIGHTERS', 4, 'Botshabelo', Decimal('23.96')),
#  ('AMELIE HELLFIGHTERS', 4, 'Funafuti', Decimal('39.96')),
#  ('AMELIE HELLFIGHTERS', 4, 'Madiun', Decimal('19.96')),
#  ('AMELIE HELLFIGHTERS', 4, 'Meixian', Decimal('27.96')),
#  ('AMELIE HELLFIGHTERS', 4, 'So Bernardo do Campo', Decimal('39.96')),
#  ('AMERICAN CIRCUS', 1, 'Callao', Decimal('43.96')),
#  ('AMERICAN CIRCUS', 1, 'Juazeiro do Norte', Decimal('19.96')),
#  ('AMERICAN CIRCUS', 2, 'Dos Quebradas', Decimal('39.96')),
#  ('AMERICAN CIRCUS', 2, 'El Fuerte', Decimal('27.96')),
#  ('AMERICAN CIRCUS', 2, 'Oulu', Decimal('19.96')),
#  ('AMERICAN CIRCUS', 3, 'Bayugan', Decimal('19.96')),
#  ('AMERICAN CIRCUS', 3, 'Bergamo', Decimal('23.96')),
#  ('AMERICAN CIRCUS', 3, 'Bijapur', Decimal('43.96')),
#  ('AMERICAN CIRCUS', 3, 'Changhwa', Decimal('19.96')),
#  ('AMERICAN CIRCUS', 3, 'Imus', Decimal('19.96')),
#  ('AMERICAN CIRCUS', 3, 'Konotop', Decimal('43.96')),
#  ('AMERICAN CIRCUS', 3, 'Nagaon', Decimal('19.96')),
#  ('AMERICAN CIRCUS', 3, 'Oulu', Decimal('19.96')),
#  ('AMERICAN CIRCUS', 4, 'Benguela', Decimal('39.96')),
#  ('AMERICAN CIRCUS', 4, 'Bydgoszcz', Decimal('19.96')),
#  ('AMERICAN CIRCUS', 4, 'Cabuyao', Decimal('35.96')),
#  ('AMERICAN CIRCUS', 4, 'Halle/Saale', Decimal('35.96')),
#  ('AMERICAN CIRCUS', 4, 'Juazeiro do Norte', Decimal('39.96')),
#  ('AMERICAN CIRCUS', 4, 'Nador', Decimal('35.96')),
#  ('AMERICAN CIRCUS', 4, 'Saint-Denis', Decimal('43.96')),
#  ('AMERICAN CIRCUS', 4, 'Tiefa', Decimal('35.96')),
#  ('AMERICAN CIRCUS', 5, 'Lipetsk', Decimal('19.96')),
#  ('AMISTAD MIDSUMMER', 2, 'Akron', Decimal('11.96')),
#  ('AMISTAD MIDSUMMER', 2, 'Mysore', Decimal('11.96')),
#  ('AMISTAD MIDSUMMER', 2, 'Shimonoseki', Decimal('11.96')),
#  ('AMISTAD MIDSUMMER', 3, 'Elista', Decimal('11.96')),
#  ('AMISTAD MIDSUMMER', 3, 'Garland', Decimal('11.96')),
#  ('AMISTAD MIDSUMMER', 3, 'Jastrzebie-Zdrj', Decimal('11.96')),
#  ('AMISTAD MIDSUMMER', 3, 'Kolpino', Decimal('15.96')),
#  ('AMISTAD MIDSUMMER', 3, 'Miyakonojo', Decimal('11.96')),
#  ('AMISTAD MIDSUMMER', 3, 'Vijayawada', Decimal('11.96')),
#  ('AMISTAD MIDSUMMER', 3, 'Zanzibar', Decimal('11.96')),
#  ('AMISTAD MIDSUMMER', 3, 's-Hertogenbosch', Decimal('11.96')),
#  ('AMISTAD MIDSUMMER', 4, 'Apeldoorn', Decimal('11.96')),
#  ('AMISTAD MIDSUMMER', 4, 'Arecibo', Decimal('11.96')),
#  ('AMISTAD MIDSUMMER', 4, 'Avellaneda', Decimal('19.96')),
#  ('AMISTAD MIDSUMMER', 4, 'Cavite', Decimal('11.96')),
#  ('AMISTAD MIDSUMMER', 4, 'Effon-Alaiye', Decimal('23.96')),
#  ('AMISTAD MIDSUMMER', 4, 'Nantou', Decimal('15.96')),
#  ('AMISTAD MIDSUMMER', 4, 'Sasebo', Decimal('11.96')),
#  ('AMISTAD MIDSUMMER', 4, 'Usak', Decimal('11.96')),
#  ('AMISTAD MIDSUMMER', 4, 'Xinxiang', Decimal('15.96')),
#  ('AMISTAD MIDSUMMER', 5, 'Imus', Decimal('11.96')),
#  ('ANACONDA CONFESSIONS', 1, 'Fengshan', Decimal('3.96')),
#  ('ANACONDA CONFESSIONS', 1, 'Tarsus', Decimal('7.96')),
#  ('ANACONDA CONFESSIONS', 2, 'Athenai', Decimal('27.96')),
#  ('ANACONDA CONFESSIONS', 2, 'Dallas', Decimal('3.96')),
#  ('ANACONDA CONFESSIONS', 2, 'Kermanshah', Decimal('7.96')),
#  ('ANACONDA CONFESSIONS', 2, 'Nanyang', Decimal('15.96')),
#  ('ANACONDA CONFESSIONS', 2, 'Otsu', Decimal('23.96')),
#  ('ANACONDA CONFESSIONS', 3, 'Botshabelo', Decimal('3.96')),
#  ('ANACONDA CONFESSIONS', 3, 'Haldia', Decimal('3.96')),
#  ('ANACONDA CONFESSIONS', 3, 'Roanoke', Decimal('23.96')),
#  ('ANACONDA CONFESSIONS', 3, 'Shanwei', Decimal('11.96')),
#  ('ANACONDA CONFESSIONS', 3, 'Uttarpara-Kotrung', Decimal('3.96')),
#  ('ANACONDA CONFESSIONS', 4, 'Batman', Decimal('23.96')),
#  ('ANACONDA CONFESSIONS', 4, 'Caracas', Decimal('7.96')),
#  ('ANACONDA CONFESSIONS', 4, 'Charlotte Amalie', Decimal('3.96')),
#  ('ANACONDA CONFESSIONS', 4, 'Jelets', Decimal('7.96')),
#  ('ANACONDA CONFESSIONS', 4, 'Molodetno', Decimal('15.96')),
#  ('ANACONDA CONFESSIONS', 4, 'Sambhal', Decimal('11.96')),
#  ('ANACONDA CONFESSIONS', 4, 'San Juan Bautista Tuxtepec', Decimal('11.96')),
#  ('ANACONDA CONFESSIONS', 4, 'Tanza', Decimal('15.96')),
#  ('ANACONDA CONFESSIONS', 4, 'Vitria de Santo Anto', Decimal('3.96')),
#  ('ANALYZE HOOSIERS', 2, 'Saint Louis', Decimal('19.96')),
#  ('ANALYZE HOOSIERS', 2, 'Xintai', Decimal('11.96')),
#  ('ANALYZE HOOSIERS', 2, 'Yuncheng', Decimal('11.96')),
#  ('ANALYZE HOOSIERS', 3, 'Bijapur', Decimal('15.96')),
#  ('ANALYZE HOOSIERS', 3, 'Ciudad del Este', Decimal('11.96')),
#  ('ANALYZE HOOSIERS', 3, 'Joliet', Decimal('11.96')),
#  ('ANALYZE HOOSIERS', 3, 'Tartu', Decimal('19.96')),
#  ('ANALYZE HOOSIERS', 4, 'Ambattur', Decimal('19.96')),
#  ('ANALYZE HOOSIERS', 4, 'Celaya', Decimal('15.96')),
#  ('ANALYZE HOOSIERS', 4, 'Citrus Heights', Decimal('19.96')),
#  ('ANALYZE HOOSIERS', 4, 'Kurashiki', Decimal('23.96')),
#  ('ANALYZE HOOSIERS', 4, 'Kuwana', Decimal('11.96')),
#  ('ANALYZE HOOSIERS', 4, 'Usak', Decimal('11.96')),
#  ('ANALYZE HOOSIERS', 4, 'Valparai', Decimal('15.96')),
#  ('ANGELS LIFE', 1, 'Adana', Decimal('27.96')),
#  ('ANGELS LIFE', 1, 'Salala', Decimal('35.96')),
#  ('ANGELS LIFE', 2, 'Arecibo', Decimal('15.96')),
#  ('ANGELS LIFE', 2, 'Kermanshah', Decimal('15.96')),
#  ('ANGELS LIFE', 2, 'Urawa', Decimal('11.96')),
#  ('ANGELS LIFE', 3, 'Fukuyama', Decimal('15.96')),
#  ('ANGELS LIFE', 3, 'Greensboro', Decimal('11.96')),
#  ('ANGELS LIFE', 3, 'Kakamigahara', Decimal('11.96')),
#  ('ANGELS LIFE', 3, 'Nagareyama', Decimal('23.96')),
#  ('ANGELS LIFE', 3, 'Salamanca', Decimal('35.96')),
#  ('ANGELS LIFE', 3, 'San Juan Bautista Tuxtepec', Decimal('27.96')),
#  ('ANGELS LIFE', 3, 'Teboksary', Decimal('27.96')),
#  ('ANGELS LIFE', 3, 'Wroclaw', Decimal('31.96')),
#  ('ANGELS LIFE', 4, 'Ambattur', Decimal('11.96')),
#  ('ANGELS LIFE', 4, 'Augusta-Richmond County', Decimal('11.96')),
#  ('ANGELS LIFE', 4, 'Carmen', Decimal('23.96')),
#  ('ANGELS LIFE', 4, 'Kakamigahara', Decimal('15.96')),
#  ('ANGELS LIFE', 4, 'Korolev', Decimal('31.96')),
#  ('ANGELS LIFE', 4, 'Olomouc', Decimal('11.96')),
#  ('ANGELS LIFE', 4, 'Rampur', Decimal('35.96')),
#  ('ANGELS LIFE', 4, 'Sharja', Decimal('27.96')),
#  ('ANGELS LIFE', 4, 'York', Decimal('11.96')),
#  ('ANNIE IDENTITY', 1, 'Jedda', Decimal('15.96')),
#  ('ANNIE IDENTITY', 1, 'Maring', Decimal('15.96')),
#  ('ANNIE IDENTITY', 1, 'Tel Aviv-Jaffa', Decimal('3.96')),
#  ('ANNIE IDENTITY', 2, 'Battambang', Decimal('11.96')),
#  ('ANNIE IDENTITY', 2, 'Ede', Decimal('23.96')),
#  ('ANNIE IDENTITY', 2, 'Goinia', Decimal('3.96')),
#  ('ANNIE IDENTITY', 2, 'Tama', Decimal('3.96')),
#  ('ANNIE IDENTITY', 3, 'Ashqelon', Decimal('19.96')),
#  ('ANNIE IDENTITY', 3, 'Czestochowa', Decimal('19.96')),
#  ('ANNIE IDENTITY', 3, 'Myingyan', Decimal('7.96')),
#  ('ANNIE IDENTITY', 3, 'Pangkal Pinang', Decimal('3.96')),
#  ('ANNIE IDENTITY', 3, 'Santa F', Decimal('11.96')),
#  ('ANNIE IDENTITY', 3, 'Shaoguan', Decimal('27.96')),
#  ('ANNIE IDENTITY', 3, 'Yuncheng', Decimal('3.96')),
#  ('ANNIE IDENTITY', 4, 'Cabuyao', Decimal('3.96')),
#  ('ANNIE IDENTITY', 4, 'Luzinia', Decimal('3.96')),
#  ('ANNIE IDENTITY', 4, 'Oyo', Decimal('3.96')),
#  ('ANNIE IDENTITY', 4, 'Szkesfehrvr', Decimal('3.96')),
#  ('ANNIE IDENTITY', 4, 'Vilnius', Decimal('7.96')),
#  ('ANNIE IDENTITY', 4, 'Zanzibar', Decimal('3.96')),
#  ('ANNIE IDENTITY', 4, 'Zaria', Decimal('23.96')),
#  ('ANNIE IDENTITY', 4, 'Zhoushan', Decimal('11.96')),
#  ('ANONYMOUS HUMAN', 2, 'Uruapan', Decimal('7.96')),
#  ('ANONYMOUS HUMAN', 2, 'Varanasi (Benares)', Decimal('3.96')),
#  ('ANONYMOUS HUMAN', 3, 'Basel', Decimal('3.96')),
#  ('ANONYMOUS HUMAN', 3, 'Ezhou', Decimal('11.96')),
#  ('ANONYMOUS HUMAN', 3, 'Kowloon and New Kowloon', Decimal('3.96')),
#  ('ANONYMOUS HUMAN', 3, 'La Romana', Decimal('3.96')),
#  ('ANONYMOUS HUMAN', 3, 'San Bernardino', Decimal('3.96')),
#  ('ANONYMOUS HUMAN', 3, 'Zhezqazghan', Decimal('7.96')),
#  ('ANONYMOUS HUMAN', 4, 'Dhaka', Decimal('3.96')),
#  ('ANONYMOUS HUMAN', 4, 'Iwakuni', Decimal('3.96')),
#  ('ANONYMOUS HUMAN', 4, 'Kamakura', Decimal('7.96')),
#  ('ANONYMOUS HUMAN', 4, 'Liepaja', Decimal('3.96')),
#  ('ANONYMOUS HUMAN', 4, 'Richmond Hill', Decimal('3.96')),
#  ('ANTHEM LUKE', 1, 'Lengshuijiang', Decimal('27.96')),
#  ('ANTHEM LUKE', 1, 'Pyongyang', Decimal('19.96')),
#  ('ANTHEM LUKE', 1, 'Uluberia', Decimal('19.96')),
#  ('ANTHEM LUKE', 2, 'Ashgabat', Decimal('19.96')),
#  ('ANTHEM LUKE', 2, 'Cuauhtmoc', Decimal('19.96')),
#  ('ANTHEM LUKE', 2, 'San Felipe del Progreso', Decimal('19.96')),
#  ('ANTHEM LUKE', 3, 'Acua', Decimal('19.96')),
#  ('ANTHEM LUKE', 3, 'Fukuyama', Decimal('19.96')),
#  ('ANTHEM LUKE', 3, 'Ozamis', Decimal('19.96')),
#  ('ANTHEM LUKE', 4, 'Boa Vista', Decimal('35.96')),
#  ('ANTHEM LUKE', 4, 'Changzhou', Decimal('19.96')),
#  ('ANTHEM LUKE', 4, 'Coacalco de Berriozbal', Decimal('19.96')),
#  ('ANTHEM LUKE', 4, 'Kirovo-Tepetsk', Decimal('19.96')),
#  ('ANTHEM LUKE', 4, 'Kuwana', Decimal('23.96')),
#  ('ANTHEM LUKE', 4, 'Lhokseumawe', Decimal('35.96')),
#  ('ANTITRUST TOMATOES', 1, 'Erlangen', Decimal('11.96')),
#  ('ANTITRUST TOMATOES', 1, 'Novoterkassk', Decimal('11.96')),
#  ('ANTITRUST TOMATOES', 2, 'Lapu-Lapu', Decimal('27.96')),
#  ('ANTITRUST TOMATOES', 2, 'Sharja', Decimal('15.96')),
#  ('ANTITRUST TOMATOES', 3, 'Malm', Decimal('11.96')),
#  ('ANTITRUST TOMATOES', 3, 'Pereira', Decimal('11.96')),
#  ('ANTITRUST TOMATOES', 4, 'Bhimavaram', Decimal('15.96')),
#  ('ANTITRUST TOMATOES', 4, 'Fuyu', Decimal('19.96')),
#  ('ANTITRUST TOMATOES', 4, 'Vijayawada', Decimal('11.96')),
#  ('ANTITRUST TOMATOES', 4, 'Ziguinchor', Decimal('11.96')),
#  ('ANYTHING SAVANNAH', 1, 'Halle/Saale', Decimal('11.96')),
#  ('ANYTHING SAVANNAH', 2, 'Araatuba', Decimal('19.96')),
#  ('ANYTHING SAVANNAH', 2, 'Mexicali', Decimal('27.96')),
#  ('ANYTHING SAVANNAH', 3, 'Cam Ranh', Decimal('15.96')),
#  ('ANYTHING SAVANNAH', 3, 'El Monte', Decimal('23.96')),
#  ('ANYTHING SAVANNAH', 3, 'Gandhinagar', Decimal('11.96')),
#  ('ANYTHING SAVANNAH', 3, 'Yangor', Decimal('31.96')),
#  ('ANYTHING SAVANNAH', 4, 'Banjul', Decimal('31.96')),
#  ('ANYTHING SAVANNAH', 4, 'Zaoyang', Decimal('11.96')),
#  ('APACHE DIVINE', 1, 'Cavite', Decimal('19.96')),
#  ('APACHE DIVINE', 1, 'Mukateve', Decimal('31.96')),
#  ('APACHE DIVINE', 1, 'So Leopoldo', Decimal('19.96')),
#  ('APACHE DIVINE', 2, 'Bamenda', Decimal('19.96')),
#  ('APACHE DIVINE', 2, 'Cam Ranh', Decimal('19.96')),
#  ('APACHE DIVINE', 2, 'Iwaki', Decimal('19.96')),
#  ('APACHE DIVINE', 2, 'Taizz', Decimal('19.96')),
#  ('APACHE DIVINE', 3, 'Balikesir', Decimal('27.96')),
#  ('APACHE DIVINE', 3, 'Boksburg', Decimal('31.96')),
#  ('APACHE DIVINE', 3, 'El Fuerte', Decimal('27.96')),
#  ('APACHE DIVINE', 3, 'Guadalajara', Decimal('19.96')),
#  ('APACHE DIVINE', 3, 'Kanazawa', Decimal('19.96')),
#  ('APACHE DIVINE', 3, 'Maikop', Decimal('23.96')),
#  ('APACHE DIVINE', 3, 'Moscow', Decimal('23.96')),
#  ('APACHE DIVINE', 3, 'Okinawa', Decimal('35.96')),
#  ('APACHE DIVINE', 3, 'Sorocaba', Decimal('19.96')),
#  ('APACHE DIVINE', 3, 'Urawa', Decimal('19.96')),
#  ('APACHE DIVINE', 3, 'Zanzibar', Decimal('19.96')),
#  ('APACHE DIVINE', 4, 'Bandar Seri Begawan', Decimal('19.96')),
#  ('APACHE DIVINE', 4, 'Carmen', Decimal('19.96')),
#  ('APACHE DIVINE', 4, 'Greensboro', Decimal('19.96')),
#  ('APACHE DIVINE', 4, 'Jaffna', Decimal('19.96')),
#  ('APACHE DIVINE', 4, 'Kimberley', Decimal('23.96')),
#  ('APACHE DIVINE', 4, 'Malm', Decimal('19.96')),
#  ('APACHE DIVINE', 4, 'Mit Ghamr', Decimal('27.96')),
#  ('APACHE DIVINE', 4, 'Oshawa', Decimal('19.96')),
#  ('APACHE DIVINE', 4, 'Pereira', Decimal('23.96')),
#  ('APACHE DIVINE', 4, 'Robamba', Decimal('19.96')),
#  ('APACHE DIVINE', 4, 'Taguig', Decimal('23.96')),
#  ('APACHE DIVINE', 4, 'Tiefa', Decimal('19.96')),
#  ('APACHE DIVINE', 4, 'York', Decimal('31.96')),
#  ('APOCALYPSE FLAMINGOS', 2, 'Kalisz', Decimal('23.96')),
#  ('APOCALYPSE FLAMINGOS', 3, 'Chandrapur', Decimal('19.96')),
#  ('APOCALYPSE FLAMINGOS', 3, 'Ikerre', Decimal('19.96')),
#  ('APOCALYPSE FLAMINGOS', 4, 'Belm', Decimal('19.96')),
#  ('APOCALYPSE FLAMINGOS', 4, 'Blumenau', Decimal('19.96')),
#  ('APOCALYPSE FLAMINGOS', 4, 'Ruse', Decimal('19.96')),
#  ('ARABIA DOGMA', 1, 'Tartu', Decimal('3.96')),
#  ('ARABIA DOGMA', 2, 'Qalyub', Decimal('3.96')),
#  ('ARABIA DOGMA', 2, 'Toulouse', Decimal('3.96')),
#  ('ARABIA DOGMA', 3, 'Amroha', Decimal('3.96')),
#  ('ARABIA DOGMA', 3, 'La Plata', Decimal('15.96')),
#  ('ARABIA DOGMA', 3, 'London', Decimal('15.96')),
#  ('ARABIA DOGMA', 3, 'Lubumbashi', Decimal('3.96')),
#  ('ARABIA DOGMA', 3, 'Monclova', Decimal('15.96')),
#  ('ARABIA DOGMA', 3, 'Tokat', Decimal('7.96')),
#  ('ARABIA DOGMA', 4, 'Changzhou', Decimal('3.96')),
#  ('ARABIA DOGMA', 4, 'Lapu-Lapu', Decimal('3.96')),
#  ('ARABIA DOGMA', 4, 'Tuguegarao', Decimal('3.96')),
#  ('ARABIA DOGMA', 4, 'Usak', Decimal('3.96')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 2, 'Arlington', Decimal('19.96')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 2, 'Bhusawal', Decimal('11.96')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 2, 'Mwene-Ditu', Decimal('23.96')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 2, 'Tonghae', Decimal('19.96')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3, 'Czestochowa', Decimal('27.96')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3, 'Higashiosaka', Decimal('15.96')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3, 'Kimberley', Decimal('11.96')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3, 'Matsue', Decimal('15.96')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3, 'Ondo', Decimal('27.96')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3, 'Parbhani', Decimal('15.96')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 3, 'Zalantun', Decimal('23.96')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4, 'Chapra', Decimal('27.96')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4, 'Dadu', Decimal('11.96')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4, 'Fuyu', Decimal('15.96')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4, 'Gaziantep', Decimal('31.96')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4, 'Goinia', Decimal('11.96')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4, 'Jamalpur', Decimal('19.96')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4, 'Kamakura', Decimal('11.96')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4, 'Myingyan', Decimal('15.96')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4, 'Rio Claro', Decimal('15.96')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4, 'Roanoke', Decimal('11.96')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4, 'Usak', Decimal('23.96')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4, 'Vicente Lpez', Decimal('31.96')),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 4, 'Zhezqazghan', Decimal('11.96')),
#  ('ARIZONA BANG', 2, 'Jalib al-Shuyukh', Decimal('23.96')),
#  ('ARIZONA BANG', 2, 'Szkesfehrvr', Decimal('11.96')),
#  ('ARIZONA BANG', 2, 'guas Lindas de Gois', Decimal('11.96')),
#  ('ARIZONA BANG', 3, 'Hamilton', Decimal('11.96')),
#  ('ARIZONA BANG', 3, 'Kowloon and New Kowloon', Decimal('31.96')),
#  ('ARIZONA BANG', 3, 'Molodetno', Decimal('19.96')),
#  ('ARIZONA BANG', 3, 'Nantou', Decimal('11.96')),
#  ('ARIZONA BANG', 3, 'Palghat (Palakkad)', Decimal('31.96')),
#  ('ARIZONA BANG', 3, 'Pontianak', Decimal('19.96')),
#  ('ARIZONA BANG', 3, 'Probolinggo', Decimal('11.96')),
#  ('ARIZONA BANG', 3, 'Rajkot', Decimal('31.96')),
#  ('ARIZONA BANG', 3, 'Salala', Decimal('11.96')),
#  ('ARIZONA BANG', 3, 'Shikarpur', Decimal('19.96')),
#  ('ARIZONA BANG', 3, 'Springs', Decimal('23.96')),
#  ('ARIZONA BANG', 3, 'Vijayawada', Decimal('27.96')),
#  ('ARIZONA BANG', 4, 'Battambang', Decimal('15.96')),
#  ('ARIZONA BANG', 4, 'Davao', Decimal('19.96')),
#  ('ARIZONA BANG', 4, 'Lancaster', Decimal('23.96')),
#  ('ARIZONA BANG', 4, 'Liepaja', Decimal('31.96')),
#  ('ARIZONA BANG', 4, 'Osmaniye', Decimal('11.96')),
#  ('ARIZONA BANG', 4, 'Saint-Denis', Decimal('11.96')),
#  ('ARMAGEDDON LOST', 1, 'Dallas', Decimal('15.96')),
#  ('ARMAGEDDON LOST', 2, 'Surakarta', Decimal('19.96')),
#  ('ARMAGEDDON LOST', 2, 'Tallahassee', Decimal('3.96')),
#  ('ARMAGEDDON LOST', 3, 'Bhavnagar', Decimal('15.96')),
#  ('ARMAGEDDON LOST', 3, 'Dzerzinsk', Decimal('23.96')),
#  ('ARMAGEDDON LOST', 3, 'Hanoi', Decimal('7.96')),
#  ('ARMAGEDDON LOST', 3, 'NDjamna', Decimal('3.96')),
#  ('ARMAGEDDON LOST', 3, 'Nanyang', Decimal('3.96')),
#  ('ARMAGEDDON LOST', 3, 'Rio Claro', Decimal('7.96')),
#  ('ARMAGEDDON LOST', 4, 'Ambattur', Decimal('11.96')),
#  ('ARMAGEDDON LOST', 4, 'Bradford', Decimal('3.96')),
#  ('ARMAGEDDON LOST', 4, 'Cheju', Decimal('7.96')),
#  ('ARMAGEDDON LOST', 4, 'Cianjur', Decimal('3.96')),
#  ('ARMAGEDDON LOST', 4, 'Hiroshima', Decimal('11.96')),
#  ('ARMAGEDDON LOST', 4, 'Luzinia', Decimal('3.96')),
#  ('ARMAGEDDON LOST', 4, 'Nakhon Sawan', Decimal('3.96')),
#  ('ARMAGEDDON LOST', 4, 'Rae Bareli', Decimal('15.96')),
#  ('ARMAGEDDON LOST', 4, 'Saint-Denis', Decimal('3.96')),
#  ('ARMAGEDDON LOST', 4, 'Szkesfehrvr', Decimal('3.96')),
#  ('ARMAGEDDON LOST', 4, 'Uijongbu', Decimal('3.96')),
#  ('ARMAGEDDON LOST', 5, 'Trshavn', Decimal('3.96')),
#  ('ARMY FLINTSTONES', 1, 'Lublin', Decimal('3.96')),
#  ('ARMY FLINTSTONES', 1, 'Sunnyvale', Decimal('15.96')),
#  ('ARMY FLINTSTONES', 2, 'Kamarhati', Decimal('3.96')),
#  ('ARMY FLINTSTONES', 2, 'Rae Bareli', Decimal('11.96')),
#  ('ARMY FLINTSTONES', 2, 'Sterling Heights', Decimal('3.96')),
#  ('ARMY FLINTSTONES', 3, 'Boa Vista', Decimal('3.96')),
#  ('ARMY FLINTSTONES', 3, 'Lengshuijiang', Decimal('3.96')),
#  ('ARMY FLINTSTONES', 3, 'Po', Decimal('15.96')),
#  ('ARMY FLINTSTONES', 3, 'Yamuna Nagar', Decimal('3.96')),
#  ('ARMY FLINTSTONES', 3, 'Yuzhou', Decimal('19.96')),
#  ('ARMY FLINTSTONES', 4, 'Aden', Decimal('3.96')),
#  ('ARMY FLINTSTONES', 4, 'Cavite', Decimal('3.96')),
#  ('ARMY FLINTSTONES', 4, 'Jodhpur', Decimal('11.96')),
#  ('ARMY FLINTSTONES', 4, 'Kurashiki', Decimal('15.96')),
#  ('ARMY FLINTSTONES', 4, 'Pune', Decimal('15.96')),
#  ('ARMY FLINTSTONES', 4, 'Skikda', Decimal('27.96')),
#  ('ARTIST COLDBLOODED', 1, 'Ogbomosho', Decimal('27.96')),
#  ('ARTIST COLDBLOODED', 1, 'Rajkot', Decimal('11.96')),
#  ('ARTIST COLDBLOODED', 2, 'Hamilton', Decimal('11.96')),
#  ('ARTIST COLDBLOODED', 2, 'Myingyan', Decimal('11.96')),
#  ('ARTIST COLDBLOODED', 2, 'Valencia', Decimal('15.96')),
#  ('ARTIST COLDBLOODED', 3, 'Funafuti', Decimal('11.96')),
#  ('ARTIST COLDBLOODED', 3, 'Jastrzebie-Zdrj', Decimal('15.96')),
#  ('ARTIST COLDBLOODED', 3, 'Mosul', Decimal('11.96')),
#  ('ARTIST COLDBLOODED', 3, 'Tafuna', Decimal('11.96')),
#  ('ARTIST COLDBLOODED', 4, 'Ashdod', Decimal('27.96')),
#  ('ARTIST COLDBLOODED', 4, 'Bijapur', Decimal('23.96')),
#  ('ARTIST COLDBLOODED', 4, 'Duisburg', Decimal('11.96')),
#  ('ARTIST COLDBLOODED', 4, 'Juazeiro do Norte', Decimal('27.96')),
#  ('ARTIST COLDBLOODED', 4, 'Lubumbashi', Decimal('23.96')),
#  ('ARTIST COLDBLOODED', 4, 'Nha Trang', Decimal('19.96')),
#  ('ARTIST COLDBLOODED', 4, 'Zaria', Decimal('11.96')),
#  ('ATLANTIS CAUSE', 1, 'Sivas', Decimal('11.96')),
#  ('ATLANTIS CAUSE', 1, 's-Hertogenbosch', Decimal('11.96')),
#  ('ATLANTIS CAUSE', 2, 'Balurghat', Decimal('11.96')),
#  ('ATLANTIS CAUSE', 2, 'Beni-Mellal', Decimal('11.96')),
#  ('ATLANTIS CAUSE', 2, 'Fuzhou', Decimal('23.96')),
#  ('ATLANTIS CAUSE', 3, 'Brockton', Decimal('11.96')),
#  ('ATLANTIS CAUSE', 3, 'Caracas', Decimal('11.96')),
#  ('ATLANTIS CAUSE', 3, 'Emmen', Decimal('11.96')),
#  ('ATLANTIS CAUSE', 3, 'Jodhpur', Decimal('11.96')),
#  ('ATLANTIS CAUSE', 3, 'Sambhal', Decimal('11.96')),
#  ('ATLANTIS CAUSE', 3, 'Sogamoso', Decimal('11.96')),
#  ('ATLANTIS CAUSE', 3, 'Tabriz', Decimal('11.96')),
#  ('ATLANTIS CAUSE', 3, 'Tanauan', Decimal('23.96')),
#  ('ATLANTIS CAUSE', 3, 'al-Manama', Decimal('23.96')),
#  ('ATLANTIS CAUSE', 3, 'guas Lindas de Gois', Decimal('11.96')),
#  ('ATLANTIS CAUSE', 4, 'Abu Dhabi', Decimal('15.96')),
#  ('ATLANTIS CAUSE', 4, 'Ashgabat', Decimal('11.96')),
#  ('ATLANTIS CAUSE', 4, 'Deba Habe', Decimal('23.96')),
#  ('ATLANTIS CAUSE', 4, 'Duisburg', Decimal('11.96')),
#  ('ATLANTIS CAUSE', 4, 'Jining', Decimal('15.96')),
#  ('ATLANTIS CAUSE', 4, 'Klerksdorp', Decimal('11.96')),
#  ('ATLANTIS CAUSE', 4, 'Pontianak', Decimal('11.96')),
#  ('ATLANTIS CAUSE', 4, 'Pudukkottai', Decimal('15.96')),
#  ('ATLANTIS CAUSE', 4, 'Xiangfan', Decimal('15.96')),
#  ('ATTACKS HATE', 2, 'Sasebo', Decimal('19.96')),
#  ('ATTACKS HATE', 2, 'Yangor', Decimal('31.96')),
#  ('ATTACKS HATE', 3, 'Aden', Decimal('31.96')),
#  ('ATTACKS HATE', 3, 'Antofagasta', Decimal('35.96')),
#  ('ATTACKS HATE', 3, 'Banjul', Decimal('35.96')),
#  ('ATTACKS HATE', 3, 'Ife', Decimal('19.96')),
#  ('ATTACKS HATE', 3, 'Munger (Monghyr)', Decimal('19.96')),
#  ('ATTACKS HATE', 3, 'Owo', Decimal('23.96')),
#  ('ATTACKS HATE', 4, 'Ashdod', Decimal('23.96')),
#  ('ATTACKS HATE', 4, 'Bern', Decimal('19.96')),
#  ('ATTACKS HATE', 4, 'Carmen', Decimal('19.96')),
#  ('ATTACKS HATE', 4, 'Ipoh', Decimal('19.96')),
#  ('ATTACKS HATE', 4, 'Matsue', Decimal('23.96')),
#  ('ATTACKS HATE', 4, 'Sumy', Decimal('35.96')),
#  ('ATTACKS HATE', 4, 'Tangail', Decimal('23.96')),
#  ('ATTACKS HATE', 4, 'Ueda', Decimal('19.96')),
#  ('ATTRACTION NEWTON', 1, 'Sincelejo', Decimal('19.96')),
#  ('ATTRACTION NEWTON', 2, 'Ezhou', Decimal('31.96')),
#  ('ATTRACTION NEWTON', 2, 'Lengshuijiang', Decimal('27.96')),
#  ('ATTRACTION NEWTON', 2, 'Nagaon', Decimal('19.96')),
#  ('ATTRACTION NEWTON', 2, 'Portoviejo', Decimal('35.96')),
#  ('ATTRACTION NEWTON', 2, 'Tete', Decimal('19.96')),
#  ('ATTRACTION NEWTON', 3, 'Changzhou', Decimal('19.96')),
#  ('ATTRACTION NEWTON', 3, 'Jakarta', Decimal('19.96')),
#  ('ATTRACTION NEWTON', 3, 'Kimberley', Decimal('35.96')),
#  ('ATTRACTION NEWTON', 3, 'Mit Ghamr', Decimal('19.96')),
#  ('ATTRACTION NEWTON', 3, 'Monywa', Decimal('19.96')),
#  ('ATTRACTION NEWTON', 3, 'Mukateve', Decimal('19.96')),
#  ('ATTRACTION NEWTON', 3, 'Patiala', Decimal('19.96')),
#  ('ATTRACTION NEWTON', 3, 'Salzburg', Decimal('19.96')),
#  ('ATTRACTION NEWTON', 3, 'Southend-on-Sea', Decimal('27.96')),
#  ('ATTRACTION NEWTON', 3, 'Zapopan', Decimal('19.96')),
#  ('ATTRACTION NEWTON', 4, 'Akishima', Decimal('31.96')),
#  ('ATTRACTION NEWTON', 4, 'Amroha', Decimal('19.96')),
#  ('ATTRACTION NEWTON', 4, 'Batna', Decimal('19.96')),
#  ('ATTRACTION NEWTON', 4, 'Fontana', Decimal('23.96')),
#  ('ATTRACTION NEWTON', 4, 'Maikop', Decimal('19.96')),
#  ('ATTRACTION NEWTON', 4, 'Maracabo', Decimal('35.96')),
#  ('ATTRACTION NEWTON', 4, 'Tongliao', Decimal('23.96')),
#  ('ATTRACTION NEWTON', 4, 'Zeleznogorsk', Decimal('31.96')),
#  ('AUTUMN CROW', 1, 'Ashgabat', Decimal('39.96')),
#  ('AUTUMN CROW', 2, 'Iwakuni', Decimal('27.96')),
#  ('AUTUMN CROW', 2, 'Stockport', Decimal('43.96')),
#  ('AUTUMN CROW', 3, 'Basel', Decimal('39.96')),
#  ('AUTUMN CROW', 3, 'Blumenau', Decimal('39.96')),
#  ('AUTUMN CROW', 3, 'Touliu', Decimal('23.96')),
#  ('AUTUMN CROW', 4, 'Aparecida de Goinia', Decimal('19.96')),
#  ('AUTUMN CROW', 4, 'Dallas', Decimal('19.96')),
#  ('AUTUMN CROW', 4, 'Fontana', Decimal('39.96')),
#  ('AUTUMN CROW', 4, 'Sincelejo', Decimal('19.96')),
#  ('AUTUMN CROW', 4, 'Tanshui', Decimal('23.96')),
#  ('BABY HALL', 1, 'Novoterkassk', Decimal('19.96')),
#  ('BABY HALL', 2, 'Memphis', Decimal('23.96')),
#  ('BABY HALL', 3, 'Lilongwe', Decimal('19.96')),
#  ('BABY HALL', 3, 'Osmaniye', Decimal('19.96')),
#  ('BABY HALL', 3, 'San Juan Bautista Tuxtepec', Decimal('19.96')),
#  ('BABY HALL', 4, 'Ilorin', Decimal('27.96')),
#  ('BABY HALL', 4, 'Lincoln', Decimal('19.96')),
#  ('BABY HALL', 4, 'Surakarta', Decimal('31.96')),
#  ('BACKLASH UNDEFEATED', 1, 'Kaliningrad', Decimal('23.96')),
#  ('BACKLASH UNDEFEATED', 1, 'Kamyin', Decimal('19.96')),
#  ('BACKLASH UNDEFEATED', 1, 'Maring', Decimal('27.96')),
#  ('BACKLASH UNDEFEATED', 2, 'Bellevue', Decimal('39.96')),
#  ('BACKLASH UNDEFEATED', 2, 'Cuauhtmoc', Decimal('39.96')),
#  ('BACKLASH UNDEFEATED', 2, 'Jedda', Decimal('19.96')),
#  ('BACKLASH UNDEFEATED', 2, 'Springs', Decimal('19.96')),
#  ('BACKLASH UNDEFEATED', 3, 'Blumenau', Decimal('43.96')),
#  ('BACKLASH UNDEFEATED', 3, 'Etawah', Decimal('39.96')),
#  ('BACKLASH UNDEFEATED', 3, 'Kursk', Decimal('39.96')),
#  ('BACKLASH UNDEFEATED', 3, 'London', Decimal('39.96')),
#  ('BACKLASH UNDEFEATED', 4, 'Elista', Decimal('35.96')),
#  ('BACKLASH UNDEFEATED', 4, 'Escobar', Decimal('35.96')),
#  ('BACKLASH UNDEFEATED', 4, 'Loja', Decimal('39.96')),
#  ('BACKLASH UNDEFEATED', 4, 'Omdurman', Decimal('35.96')),
#  ('BACKLASH UNDEFEATED', 4, 'Pontianak', Decimal('35.96')),
#  ('BACKLASH UNDEFEATED', 4, 'Tarlac', Decimal('31.96')),
#  ('BACKLASH UNDEFEATED', 4, 'Uijongbu', Decimal('23.96')),
#  ('BACKLASH UNDEFEATED', 4, 'Uttarpara-Kotrung', Decimal('39.96')),
#  ('BADMAN DAWN', 2, 'Huixquilucan', Decimal('11.96')),
#  ('BADMAN DAWN', 2, 'Rizhao', Decimal('11.96')),
#  ('BADMAN DAWN', 2, 'Tanza', Decimal('23.96')),
#  ('BADMAN DAWN', 2, 'Tieli', Decimal('19.96')),
#  ('BADMAN DAWN', 3, 'Alvorada', Decimal('11.96')),
#  ('BADMAN DAWN', 3, 'Fukuyama', Decimal('11.96')),
#  ('BADMAN DAWN', 3, 'Hami', Decimal('23.96')),
#  ('BADMAN DAWN', 3, 'Najafabad', Decimal('11.96')),
#  ('BADMAN DAWN', 3, 'Simferopol', Decimal('15.96')),
#  ('BADMAN DAWN', 3, 'Soshanguve', Decimal('11.96')),
#  ('BADMAN DAWN', 4, 'Abha', Decimal('11.96')),
#  ('BADMAN DAWN', 4, 'Balikesir', Decimal('11.96')),
#  ('BADMAN DAWN', 4, 'Beira', Decimal('19.96')),
#  ('BADMAN DAWN', 4, 'Citt del Vaticano', Decimal('15.96')),
#  ('BADMAN DAWN', 4, 'Oyo', Decimal('11.96')),
#  ('BADMAN DAWN', 4, 'Ozamis', Decimal('11.96')),
#  ('BADMAN DAWN', 4, 'Pak Kret', Decimal('27.92')),
#  ('BADMAN DAWN', 4, 'Serpuhov', Decimal('11.96')),
#  ('BADMAN DAWN', 4, 'Siliguri (Shiliguri)', Decimal('11.96')),
#  ('BADMAN DAWN', 4, 'Zaoyang', Decimal('15.96')),
#  ('BAKED CLEOPATRA', 1, 'Okayama', Decimal('11.96')),
#  ('BAKED CLEOPATRA', 2, 'Tarsus', Decimal('11.96')),
#  ('BAKED CLEOPATRA', 3, 'Garden Grove', Decimal('23.96')),
#  ('BAKED CLEOPATRA', 3, 'Hiroshima', Decimal('15.96')),
#  ('BAKED CLEOPATRA', 3, 'Madiun', Decimal('11.96')),
#  ('BAKED CLEOPATRA', 3, 'Santa Rosa', Decimal('27.96')),
#  ('BAKED CLEOPATRA', 4, 'Acua', Decimal('19.96')),
#  ('BAKED CLEOPATRA', 4, 'Bergamo', Decimal('27.96')),
#  ('BAKED CLEOPATRA', 4, 'Gandhinagar', Decimal('11.96')),
#  ('BAKED CLEOPATRA', 4, 'Hodeida', Decimal('27.96')),
#  ('BAKED CLEOPATRA', 4, 'Ourense (Orense)', Decimal('27.96')),
#  ('BAKED CLEOPATRA', 4, 'Phnom Penh', Decimal('11.96')),
#  ('BAKED CLEOPATRA', 4, 'San Miguel de Tucumn', Decimal('11.96')),
#  ('BAKED CLEOPATRA', 4, 'Valencia', Decimal('31.96')),
#  ('BAKED CLEOPATRA', 4, 'Vila Velha', Decimal('31.96')),
#  ('BAKED CLEOPATRA', 5, 'Haiphong', Decimal('11.96')),
#  ('BALLOON HOMEWARD', 1, 'Witten', Decimal('27.96')),
#  ('BALLOON HOMEWARD', 2, 'Botosani', Decimal('15.96')),
#  ('BALLOON HOMEWARD', 2, 'Datong', Decimal('11.96')),
#  ('BALLOON HOMEWARD', 2, 'Pak Kret', Decimal('11.96')),
#  ('BALLOON HOMEWARD', 2, 'Plock', Decimal('15.96')),
#  ('BALLOON HOMEWARD', 2, 'Vitria de Santo Anto', Decimal('11.96')),
#  ('BALLOON HOMEWARD', 3, 'Allende', Decimal('11.96')),
#  ('BALLOON HOMEWARD', 3, 'Araatuba', Decimal('11.96')),
#  ('BALLOON HOMEWARD', 3, 'Binzhou', Decimal('27.96')),
#  ('BALLOON HOMEWARD', 3, 'Cianjur', Decimal('11.96')),
#  ('BALLOON HOMEWARD', 3, 'Fuyu', Decimal('15.96')),
#  ('BALLOON HOMEWARD', 3, 'Livorno', Decimal('15.96')),
#  ('BALLOON HOMEWARD', 3, 'Salzburg', Decimal('27.96')),
#  ('BALLOON HOMEWARD', 3, 'Udaipur', Decimal('23.96')),
#  ('BALLOON HOMEWARD', 3, 'Zaoyang', Decimal('11.96')),
#  ('BALLOON HOMEWARD', 4, 'Beira', Decimal('11.96')),
#  ('BALLOON HOMEWARD', 4, 'Beni-Mellal', Decimal('11.96')),
#  ('BALLOON HOMEWARD', 4, 'Bucuresti', Decimal('27.96')),
#  ('BALLOON HOMEWARD', 4, 'Junan', Decimal('19.96')),
#  ('BALLOON HOMEWARD', 4, 'Roanoke', Decimal('11.96')),
#  ('BALLOON HOMEWARD', 4, 'Yantai', Decimal('15.96')),
#  ('BALLOON HOMEWARD', 4, 'Yerevan', Decimal('11.96')),
#  ('BALLOON HOMEWARD', 4, 'Yinchuan', Decimal('27.96')),
#  ('BALLROOM MOCKINGBIRD', 1, 'Valparai', Decimal('3.96')),
#  ('BALLROOM MOCKINGBIRD', 2, 'Compton', Decimal('3.96')),
#  ('BALLROOM MOCKINGBIRD', 3, 'Cam Ranh', Decimal('3.96')),
#  ('BALLROOM MOCKINGBIRD', 3, 'Omiya', Decimal('3.96')),
#  ('BALLROOM MOCKINGBIRD', 3, 'Tychy', Decimal('7.96')),
#  ('BALLROOM MOCKINGBIRD', 4, 'Effon-Alaiye', Decimal('3.96')),
#  ('BALLROOM MOCKINGBIRD', 4, 'Malm', Decimal('11.96')),
#  ('BALLROOM MOCKINGBIRD', 4, 'Tarsus', Decimal('3.96')),
#  ('BANG KWAI', 2, 'Torren', Decimal('15.96')),
#  ('BANG KWAI', 3, 'Coatzacoalcos', Decimal('15.96')),
#  ('BANG KWAI', 3, 'Pontianak', Decimal('11.96')),
#  ('BANG KWAI', 4, 'Boa Vista', Decimal('11.96')),
#  ('BANG KWAI', 4, 'Nagaon', Decimal('11.96')),
#  ('BANG KWAI', 4, 'Shikarpur', Decimal('11.96')),
#  ('BANG KWAI', 5, 'Taizz', Decimal('11.96')),
#  ('BANGER PINOCCHIO', 1, 'Shubra al-Khayma', Decimal('3.96')),
#  ('BANGER PINOCCHIO', 1, 'Tonghae', Decimal('3.96')),
#  ('BANGER PINOCCHIO', 2, 'Cabuyao', Decimal('7.96')),
#  ('BANGER PINOCCHIO', 2, 'Cavite', Decimal('3.96')),
#  ('BANGER PINOCCHIO', 2, 'Munger (Monghyr)', Decimal('3.96')),
#  ('BANGER PINOCCHIO', 2, 'Novoterkassk', Decimal('11.96')),
#  ('BANGER PINOCCHIO', 2, 'Siliguri (Shiliguri)', Decimal('3.96')),
#  ('BANGER PINOCCHIO', 3, 'Abha', Decimal('7.96')),
#  ('BANGER PINOCCHIO', 3, 'Binzhou', Decimal('3.96')),
#  ('BANGER PINOCCHIO', 3, 'Emeishan', Decimal('11.96')),
#  ('BANGER PINOCCHIO', 3, 'Kaduna', Decimal('3.96')),
#  ('BANGER PINOCCHIO', 3, 'Ocumare del Tuy', Decimal('3.96')),
#  ('BANGER PINOCCHIO', 3, 'Simferopol', Decimal('19.96')),
#  ('BANGER PINOCCHIO', 3, 'Tama', Decimal('3.96')),
#  ('BANGER PINOCCHIO', 4, 'Almirante Brown', Decimal('3.96')),
#  ('BANGER PINOCCHIO', 4, 'Bamenda', Decimal('11.96')),
#  ('BANGER PINOCCHIO', 4, 'Jakarta', Decimal('3.96')),
#  ('BANGER PINOCCHIO', 4, 'Jinchang', Decimal('19.96')),
#  ('BANGER PINOCCHIO', 4, 'Katihar', Decimal('15.96')),
#  ('BANGER PINOCCHIO', 4, 'Tychy', Decimal('11.96')),
#  ('BANGER PINOCCHIO', 4, 'Vancouver', Decimal('3.96')),
#  ('BANGER PINOCCHIO', 4, 'Vicente Lpez', Decimal('3.96')),
#  ('BARBARELLA STREETCAR', 1, 'Alvorada', Decimal('11.96')),
#  ('BARBARELLA STREETCAR', 1, 'Bucuresti', Decimal('23.96')),
#  ('BARBARELLA STREETCAR', 1, 'Kamakura', Decimal('11.96')),
#  ('BARBARELLA STREETCAR', 2, 'Ashdod', Decimal('11.96')),
#  ('BARBARELLA STREETCAR', 2, 'Cuernavaca', Decimal('11.96')),
#  ('BARBARELLA STREETCAR', 2, 'Ezeiza', Decimal('11.96')),
#  ('BARBARELLA STREETCAR', 2, 'Graz', Decimal('11.96')),
#  ('BARBARELLA STREETCAR', 2, 'Uruapan', Decimal('11.96')),
#  ('BARBARELLA STREETCAR', 3, 'Abha', Decimal('19.96')),
#  ('BARBARELLA STREETCAR', 3, 'Bellevue', Decimal('11.96')),
#  ('BARBARELLA STREETCAR', 3, 'Gandhinagar', Decimal('15.96')),
#  ('BARBARELLA STREETCAR', 3, 'Huixquilucan', Decimal('11.96')),
#  ('BARBARELLA STREETCAR', 3, 'Ikerre', Decimal('15.96')),
#  ('BARBARELLA STREETCAR', 3, 'Maring', Decimal('11.96')),
#  ('BARBARELLA STREETCAR', 3, 'Richmond Hill', Decimal('19.96')),
#  ('BARBARELLA STREETCAR', 3, 'Sal', Decimal('23.96')),
#  ('BARBARELLA STREETCAR', 3, 'Yuncheng', Decimal('23.96')),
#  ('BARBARELLA STREETCAR', 4, 'Hubli-Dharwad', Decimal('15.96')),
#  ('BARBARELLA STREETCAR', 4, 'Meixian', Decimal('23.96')),
#  ('BARBARELLA STREETCAR', 4, 'Miraj', Decimal('15.96')),
#  ('BARBARELLA STREETCAR', 4, 'Moscow', Decimal('11.96')),
#  ('BARBARELLA STREETCAR', 4, 'Niznekamsk', Decimal('15.96')),
#  ('BARBARELLA STREETCAR', 4, 'Qomsheh', Decimal('15.96')),
#  ('BARBARELLA STREETCAR', 4, 'South Hill', Decimal('11.96')),
#  ('BARBARELLA STREETCAR', 4, 'Tabriz', Decimal('11.96')),
#  ('BAREFOOT MANCHURIAN', 1, 'Juazeiro do Norte', Decimal('27.96')),
#  ('BAREFOOT MANCHURIAN', 2, 'Halifax', Decimal('19.96')),
#  ('BAREFOOT MANCHURIAN', 2, 'Jelets', Decimal('15.96')),
#  ('BAREFOOT MANCHURIAN', 2, 'Madiun', Decimal('15.96')),
#  ('BAREFOOT MANCHURIAN', 3, 'Basel', Decimal('11.96')),
#  ('BAREFOOT MANCHURIAN', 3, 'Fukuyama', Decimal('11.96')),
#  ('BAREFOOT MANCHURIAN', 3, 'Halisahar', Decimal('11.96')),
#  ('BAREFOOT MANCHURIAN', 3, 'Kuwana', Decimal('11.96')),
#  ('BAREFOOT MANCHURIAN', 3, 'Pontianak', Decimal('23.96')),
#  ('BAREFOOT MANCHURIAN', 3, 'Torren', Decimal('11.96')),
#  ('BAREFOOT MANCHURIAN', 4, 'Adoni', Decimal('11.96')),
#  ('BAREFOOT MANCHURIAN', 4, 'Guadalajara', Decimal('11.96')),
#  ('BAREFOOT MANCHURIAN', 4, 'Haiphong', Decimal('11.96')),
#  ('BAREFOOT MANCHURIAN', 4, 'Jastrzebie-Zdrj', Decimal('11.96')),
#  ('BAREFOOT MANCHURIAN', 4, 'Kitwe', Decimal('19.96')),
#  ('BAREFOOT MANCHURIAN', 4, 'Le Mans', Decimal('11.96')),
#  ('BAREFOOT MANCHURIAN', 4, 'Ljubertsy', Decimal('11.96')),
#  ('BAREFOOT MANCHURIAN', 4, 'al-Manama', Decimal('11.96')),
#  ('BASIC EASY', 1, 'Tianjin', Decimal('11.96')),
#  ('BASIC EASY', 2, 'Shimoga', Decimal('11.96')),
#  ('BASIC EASY', 2, 'Sincelejo', Decimal('11.96')),
#  ('BASIC EASY', 3, 'Akishima', Decimal('15.96')),
#  ('BASIC EASY', 3, 'Bayugan', Decimal('23.96')),
#  ('BASIC EASY', 3, 'Escobar', Decimal('31.96')),
#  ('BASIC EASY', 3, 'Jurez', Decimal('15.96')),
#  ('BASIC EASY', 3, 'Konotop', Decimal('11.96')),
#  ('BASIC EASY', 3, 'Santiago de Compostela', Decimal('11.96')),
#  ('BASIC EASY', 3, 'Vancouver', Decimal('23.96')),
#  ('BASIC EASY', 3, 'Ziguinchor', Decimal('11.96')),
#  ('BASIC EASY', 4, 'Batman', Decimal('15.96')),
#  ('BASIC EASY', 4, 'Haining', Decimal('11.96')),
#  ('BASIC EASY', 4, 'Imus', Decimal('11.96')),
#  ('BASIC EASY', 4, 'Lubumbashi', Decimal('27.96')),
#  ('BASIC EASY', 4, 'Novi Sad', Decimal('11.96')),
#  ('BASIC EASY', 4, 'Pjatigorsk', Decimal('11.96')),
#  ('BASIC EASY', 4, 'Robamba', Decimal('15.96')),
#  ('BASIC EASY', 4, 'Santa Rosa', Decimal('31.96')),
#  ('BASIC EASY', 4, 'Simferopol', Decimal('27.96')),
#  ('BASIC EASY', 5, 'Laohekou', Decimal('11.96')),
#  ('BEACH HEARTBREAKERS', 1, 'Almirante Brown', Decimal('11.96')),
#  ('BEACH HEARTBREAKERS', 1, 'Katihar', Decimal('11.96')),
#  ('BEACH HEARTBREAKERS', 2, 'Cuautla', Decimal('11.96')),
#  ('BEACH HEARTBREAKERS', 2, 'Kilis', Decimal('19.96')),
#  ('BEACH HEARTBREAKERS', 2, 'Novoterkassk', Decimal('11.96')),
#  ('BEACH HEARTBREAKERS', 3, 'Bijapur', Decimal('11.96')),
#  ('BEACH HEARTBREAKERS', 3, 'Caracas', Decimal('19.96')),
#  ('BEACH HEARTBREAKERS', 3, 'Crdoba', Decimal('11.96')),
#  ('BEACH HEARTBREAKERS', 3, 'Hsichuh', Decimal('11.96')),
#  ('BEACH HEARTBREAKERS', 3, 'Quilmes', Decimal('15.96')),
#  ('BEACH HEARTBREAKERS', 3, 'Sterling Heights', Decimal('23.96')),
#  ('BEACH HEARTBREAKERS', 4, 'Kingstown', Decimal('23.96')),
#  ('BEACH HEARTBREAKERS', 4, 'Lungtan', Decimal('11.96')),
#  ('BEACH HEARTBREAKERS', 4, 'Mysore', Decimal('11.96')),
#  ('BEACH HEARTBREAKERS', 4, 'Pathankot', Decimal('23.96')),
#  ('BEACH HEARTBREAKERS', 4, 'Ruse', Decimal('11.96')),
#  ('BEACH HEARTBREAKERS', 4, 'Xiangtan', Decimal('11.96')),
#  ('BEAR GRACELAND', 1, 'Pingxiang', Decimal('15.96')),
#  ('BEAR GRACELAND', 1, 'Tabuk', Decimal('27.96')),
#  ('BEAR GRACELAND', 1, 'Uijongbu', Decimal('11.96')),
#  ('BEAR GRACELAND', 2, 'Bchar', Decimal('11.96')),
#  ('BEAR GRACELAND', 2, 'Bhopal', Decimal('11.96')),
#  ('BEAR GRACELAND', 2, 'Nakhon Sawan', Decimal('23.96')),
#  ('BEAR GRACELAND', 2, 'South Hill', Decimal('11.96')),
#  ('BEAR GRACELAND', 3, 'Angra dos Reis', Decimal('31.96')),
#  ('BEAR GRACELAND', 3, 'Juazeiro do Norte', Decimal('31.96')),
#  ('BEAR GRACELAND', 3, 'Olomouc', Decimal('15.96')),
#  ('BEAR GRACELAND', 3, 'Pune', Decimal('23.96')),
#  ('BEAR GRACELAND', 3, 'Rio Claro', Decimal('19.96')),
#  ('BEAR GRACELAND', 3, 'Robamba', Decimal('27.96')),
#  ('BEAR GRACELAND', 3, 'Tiefa', Decimal('15.96')),
#  ('BEAR GRACELAND', 4, 'Addis Abeba', Decimal('11.96')),
#  ('BEAR GRACELAND', 4, 'Ahmadnagar', Decimal('27.96')),
#  ('BEAR GRACELAND', 4, 'Bhilwara', Decimal('11.96')),
#  ('BEAR GRACELAND', 4, 'Czestochowa', Decimal('19.96')),
#  ('BEAR GRACELAND', 4, 'Lapu-Lapu', Decimal('19.96')),
#  ('BEAR GRACELAND', 4, 'Liaocheng', Decimal('31.96')),
#  ('BEAR GRACELAND', 4, 'Mardan', Decimal('11.96')),
#  ('BEAR GRACELAND', 4, 'Shenzhen', Decimal('11.96')),
#  ('BEAST HUNCHBACK', 1, 'Jinzhou', Decimal('27.96')),
#  ('BEAST HUNCHBACK', 2, 'Faaa', Decimal('19.96')),
#  ('BEAST HUNCHBACK', 2, 'Nanyang', Decimal('19.96')),
#  ('BEAST HUNCHBACK', 3, 'Duisburg', Decimal('19.96')),
#  ('BEAST HUNCHBACK', 3, 'Omiya', Decimal('43.96')),
#  ('BEAST HUNCHBACK', 3, 'Sincelejo', Decimal('35.96')),
#  ('BEAST HUNCHBACK', 4, 'Chandrapur', Decimal('19.96')),
#  ('BEAST HUNCHBACK', 4, 'Chiayi', Decimal('19.96')),
#  ('BEAST HUNCHBACK', 4, 'Guadalajara', Decimal('43.96')),
#  ('BEAST HUNCHBACK', 4, 'Kolpino', Decimal('31.96')),
#  ('BEAST HUNCHBACK', 4, 'Zaoyang', Decimal('23.96')),
#  ('BEAUTY GREASE', 1, 'Denizli', Decimal('27.96')),
#  ('BEAUTY GREASE', 2, 'Barcelona', Decimal('19.96')),
#  ('BEAUTY GREASE', 2, 'Daugavpils', Decimal('35.96')),
#  ('BEAUTY GREASE', 2, 'Huixquilucan', Decimal('19.96')),
#  ('BEAUTY GREASE', 3, 'Davao', Decimal('19.96')),
#  ('BEAUTY GREASE', 3, 'Firozabad', Decimal('19.96')),
#  ('BEAUTY GREASE', 3, 'Jaffna', Decimal('19.96')),
#  ('BEAUTY GREASE', 3, 'Kursk', Decimal('35.96')),
#  ('BEAUTY GREASE', 3, 'Lancaster', Decimal('35.96')),
#  ('BEAUTY GREASE', 3, 'Mwene-Ditu', Decimal('23.96')),
#  ('BEAUTY GREASE', 3, 'Richmond Hill', Decimal('19.96')),
#  ('BEAUTY GREASE', 3, 'Ziguinchor', Decimal('19.96')),
#  ('BEAUTY GREASE', 4, 'Acua', Decimal('19.96')),
#  ('BEAUTY GREASE', 4, 'Arlington', Decimal('19.96')),
#  ('BEAUTY GREASE', 4, 'Bhopal', Decimal('19.96')),
#  ('BEAUTY GREASE', 4, 'Dhule (Dhulia)', Decimal('31.96')),
#  ('BEAUTY GREASE', 4, 'Hsichuh', Decimal('19.96')),
#  ('BEAUTY GREASE', 4, 'Kamarhati', Decimal('27.96')),
#  ('BEAUTY GREASE', 4, 'Nezahualcyotl', Decimal('27.96')),
#  ('BEAUTY GREASE', 4, 'Omdurman', Decimal('19.96')),
#  ('BEAUTY GREASE', 4, 'Syktyvkar', Decimal('23.96')),
#  ('BEAUTY GREASE', 4, 'Zhezqazghan', Decimal('19.96')),
#  ('BED HIGHBALL', 3, 'Bhimavaram', Decimal('15.96')),
#  ('BED HIGHBALL', 3, 'Liaocheng', Decimal('11.96')),
#  ('BED HIGHBALL', 3, 'San Miguel de Tucumn', Decimal('11.96')),
#  ('BED HIGHBALL', 4, 'Iligan', Decimal('11.96')),
#  ('BED HIGHBALL', 4, 'Kursk', Decimal('23.96')),
#  ('BED HIGHBALL', 4, 'Santo Andr', Decimal('23.96')),
#  ('BEDAZZLED MARRIED', 1, 'Angra dos Reis', Decimal('7.96')),
#  ('BEDAZZLED MARRIED', 2, 'Balurghat', Decimal('3.96')),
#  ('BEDAZZLED MARRIED', 2, 'Myingyan', Decimal('3.96')),
#  ('BEDAZZLED MARRIED', 3, 'Baybay', Decimal('3.96')),
#  ('BEDAZZLED MARRIED', 3, 'Duisburg', Decimal('3.96')),
#  ('BEDAZZLED MARRIED', 3, 'Le Mans', Decimal('7.96')),
#  ('BEDAZZLED MARRIED', 3, 'Naju', Decimal('3.96')),
#  ('BEDAZZLED MARRIED', 3, 'San Felipe de Puerto Plata', Decimal('3.96')),
#  ('BEDAZZLED MARRIED', 4, 'Binzhou', Decimal('7.96')),
#  ('BEDAZZLED MARRIED', 4, 'Naju', Decimal('3.96')),
#  ('BEDAZZLED MARRIED', 4, 'Serpuhov', Decimal('3.96')),
#  ('BEDAZZLED MARRIED', 4, 'Shanwei', Decimal('7.96')),
#  ...]

# %%
# %%time
# %%sql
SELECT f.title, EXTRACT(month FROM p.payment_date) as month, ci.city, sum(p.amount) as revenue
FROM payment p
JOIN rental r    ON ( p.rental_id = r.rental_id )
JOIN inventory i ON ( r.inventory_id = i.inventory_id )
JOIN film f ON ( i.film_id = f.film_id)
JOIN customer c  ON ( p.customer_id = c.customer_id )
JOIN address a ON ( c.address_id = a.address_id )
JOIN city ci ON ( a.city_id = ci.city_id )
group by (f.title, month, ci.city)
order by f.title, month, ci.city, revenue desc;

# %% [markdown]
# # Conclusion

# %% [markdown]
# - We were able to show that a start schema is easier to understand
# - Evidence that is more performantm

# %%
# !PGPASSWORD=student pg_dump -h 127.0.0.1 -U student pagila > Data/pagila-star.sql
